# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
response = requests.get("https://en.wikipedia.org/wiki/List_of_programming_languages")

# %%
bs = BeautifulSoup(response.text, 'lxml')
data = bs.find_all("div", {"class": "div-col"})

# %%
listed = str(data).split('</a></li>')
listed.pop(0)
# Out:
# '[<div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/A_Sharp_(.NET)" title="A Sharp (.NET)">A.NET (A#/A sharp)'

# %%
listed
# Out:
# ['\n<li><a href="/wiki/A-0_System" title="A-0 System">A-0 System',
#  '\n<li><a href="/wiki/A%2B_(programming_language)" title="A+ (programming language)">A+ (A plus)',
#  '\n<li><a href="/wiki/ABAP" title="ABAP">ABAP',
#  '\n<li><a href="/wiki/ABC_(programming_language)" title="ABC (programming language)">ABC',
#  '\n<li><a href="/wiki/ABC_ALGOL" title="ABC ALGOL">ABC ALGOL',
#  '\n<li><a href="/wiki/ACC_(programming_language)" title="ACC (programming language)">ACC',
#  '\n<li><a class="mw-redirect" href="/wiki/Accent_(programming_language)" title="Accent (programming language)">Accent (Rational Synergy)',
#  '\n<li><a href="/wiki/Distributed_Application_Specification_Language" title="Distributed Application Specification Language">Ace DASL (Distributed Application Specification Language)',
#  '\n<li><a href="/wiki/Action!_(programming_language)" title="Action! (programming language)">Action!',
#  '\n<li><a href="/wiki/ActionScript" title="ActionScript">ActionScript',
#  '\n<li><a href="/wiki/Actor_(programming_language)" title="Actor (programming language)">Actor',
#  '\n<li><a href="/wiki/Ada_(programming_language)" title="Ada (programming language)">Ada</a> – <a href="/wiki/ISO/IEC_8652" title="ISO/IEC 8652">ISO/IEC 8652',
#  '\n<li><a class="mw-redirect" href="/wiki/Adenine_(programming_language)" title="Adenine (programming language)">Adenine (Haystack)',
#  '\n<li><a href="/wiki/AdvPL" title="AdvPL">AdvPL',
#  '\n<li><a class="mw-redirect" href="/wiki/Agda_(theorem_prover)" title="Agda (theorem prover)">Agda',
#  '\n<li><a class="mw-redirect" href="/wiki/Agilent_VEE" title="Agilent VEE">Agilent VEE (Keysight VEE)',
#  '\n<li><a href="/wiki/Agora_(programming_language)" title="Agora (programming language)">Agora',
#  '\n<li><a href="/wiki/AIMMS" title="AIMMS">AIMMS',
#  '\n<li><a href="/wiki/Aldor" title="Aldor">Aldor',
#  '\n<li><a href="/wiki/Alef_(programming_language)" title="Alef (programming language)">Alef',
#  '\n<li><a href="/wiki/Algebraic_Logic_Functional_programming_language" title="Algebraic Logic Functional programming language">ALF',
#  '\n<li><a href="/wiki/ALGOL_58" title="ALGOL 58">ALGOL 58',
#  '\n<li><a href="/wiki/ALGOL_60" title="ALGOL 60">ALGOL 60',
#  '\n<li><a href="/wiki/ALGOL_68" title="ALGOL 68">ALGOL 68',
#  '\n<li><a href="/wiki/ALGOL_W" title="ALGOL W">ALGOL W',
#  '\n<li><a href="/wiki/Alice_(programming_language)" title="Alice (programming language)">Alice (Alice ML)',
#  '\n<li><a href="/wiki/Alma-0" title="Alma-0">Alma-0',
#  '\n<li><a href="/wiki/AmbientTalk" title="AmbientTalk">AmbientTalk',
#  '\n<li><a href="/wiki/Amiga_E" title="Amiga E">Amiga E',
#  '\n<li><a href="/wiki/AMPL" title="AMPL">AMPL',
#  '\n<li><a href="/wiki/%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA" title="Аналитик">Analitik',
#  '\n<li><a href="/wiki/AngelScript" title="AngelScript">AngelScript',
#  '\n<li><a href="/wiki/Apache_Pig" title="Apache Pig">Apache Pig latin',
#  '\n<li><a class="mw-redirect" href="/wiki/Apex_(programming_language)" title="Apex (programming language)">Apex (Salesforce.com, Inc)',
#  '\n<li><a href="/wiki/APL_(programming_language)" title="APL (programming language)">APL',
#  '\n<li><a class="mw-redirect" href="/wiki/App_Inventor_for_Android_(programming_language)" title="App Inventor for Android (programming language)">App Inventor for Android\'s visual block language (MIT App Inventor)',
#  '\n<li><a href="/wiki/AppleScript" title="AppleScript">AppleScript',
#  '\n<li><a href="/wiki/APT_(programming_language)" title="APT (programming language)">APT',
#  '\n<li><a href="/wiki/Arc_(programming_language)" title="Arc (programming language)">Arc',
#  '\n<li><a href="/wiki/ARexx" title="ARexx">ARexx',
#  '\n<li><a href="/wiki/Argus_(programming_language)" title="Argus (programming language)">Argus',
#  '\n<li><a href="/wiki/Assembly_language" title="Assembly language">Assembly language (ASM)',
#  '\n<li><a href="/wiki/AutoHotkey" title="AutoHotkey">AutoHotkey',
#  '\n<li><a href="/wiki/AutoIt" title="AutoIt">AutoIt',
#  '\n<li><a href="/wiki/AutoLISP" title="AutoLISP">AutoLISP / Visual LISP',
#  '\n<li><a href="/wiki/Averest" title="Averest">Averest',
#  '\n<li><a href="/wiki/AWK" title="AWK">AWK',
#  '\n<li><a href="/wiki/Axum_(programming_language)" title="Axum (programming language)">Axum',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/B_(programming_language)" title="B (programming language)">B',
#  '\n<li><a href="/wiki/Babbage_(programming_language)" title="Babbage (programming language)">Babbage',
#  '\n<li><a href="/wiki/Ballerina_(programming_language)" title="Ballerina (programming language)">Ballerina',
#  '\n<li><a href="/wiki/Bash_(Unix_shell)" title="Bash (Unix shell)">Bash',
#  '\n<li><a href="/wiki/BASIC" title="BASIC">BASIC',
#  '\n<li><a href="/wiki/Batch_file" title="Batch file">Batch file (Windows/MS-DOS)',
#  '\n<li><a href="/wiki/Bc_(programming_language)" title="Bc (programming language)">bc (basic calculator)',
#  '\n<li><a href="/wiki/BCPL" title="BCPL">BCPL',
#  '\n<li><a href="/wiki/BeanShell" title="BeanShell">BeanShell',
#  '\n<li><a href="/wiki/BETA_(programming_language)" title="BETA (programming language)">BETA',
#  '\n<li><a class="mw-redirect" href="/wiki/BLISS_(programming_language)" title="BLISS (programming language)">BLISS',
#  '\n<li><a href="/wiki/Blockly" title="Blockly">Blockly',
#  '\n<li><a href="/wiki/BlooP_and_FlooP" title="BlooP and FlooP">BlooP',
#  '\n<li><a href="/wiki/Boo_(programming_language)" title="Boo (programming language)">Boo',
#  '\n<li><a href="/wiki/Boomerang_(programming_language)" title="Boomerang (programming language)">Boomerang',
#  '\n<li><a href="/wiki/Bosque_(programming_language)" title="Bosque (programming language)">Bosque',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/C_(programming_language)" title="C (programming language)">C</a> – ISO/IEC 9899</li>\n<li><a href="/wiki/C--" title="C--">C--</a> (C minus minus)</li>\n<li><a href="/wiki/C%2B%2B" title="C++">C++</a> (C plus plus) – ISO/IEC 14882</li>\n<li><a href="/wiki/C*" title="C*">C*',
#  '\n<li><a href="/wiki/C_Sharp_(programming_language)" title="C Sharp (programming language)">C#</a> (C sharp) – ISO/IEC 23270</li>\n<li><a href="/wiki/C/AL" title="C/AL">C/AL',
#  '\n<li><a href="/wiki/Cach%C3%A9_ObjectScript" title="Caché ObjectScript">Caché ObjectScript',
#  '\n<li><a class="mw-redirect" href="/wiki/C_Shell" title="C Shell">C Shell (csh)',
#  '\n<li><a href="/wiki/Caml" title="Caml">Caml',
#  '\n<li><a href="/wiki/Carbon_(programming_language)" title="Carbon (programming language)">Carbon',
#  '\n<li><a href="/wiki/Catrobat" title="Catrobat">Catrobat',
#  '\n<li><a class="mw-redirect" href="/wiki/Cayenne_(programming_language)" title="Cayenne (programming language)">Cayenne (Lennart Augustsson)',
#  '\n<li><a href="/wiki/CDuce" title="CDuce">CDuce',
#  '\n<li><a href="/wiki/Cecil_(programming_language)" title="Cecil (programming language)">Cecil',
#  '\n<li><a href="/wiki/CESIL" title="CESIL">CESIL (Computer Education in Schools Instruction Language)',
#  '\n<li><a href="/wiki/C%C3%A9u_(programming_language)" title="Céu (programming language)">Céu',
#  '\n<li><a href="/wiki/Ceylon_(programming_language)" title="Ceylon (programming language)">Ceylon',
#  '\n<li><a href="/wiki/CFEngine" title="CFEngine">CFEngine',
#  '\n<li><a href="/wiki/Cg_(programming_language)" title="Cg (programming language)">Cg (High-Level Shader/Shading Language [HLSL])',
#  '\n<li><a href="/wiki/Ch_(computer_programming)" title="Ch (computer programming)">Ch',
#  '\n<li><a href="/wiki/Chapel_(programming_language)" title="Chapel (programming language)">Chapel (Cascade High Productivity Language)',
#  '\n<li><a class="mw-redirect" href="/wiki/Charm_(language)" title="Charm (language)">Charm',
#  '\n<li><a href="/wiki/CHILL" title="CHILL">CHILL',
#  '\n<li><a href="/wiki/CHIP-8" title="CHIP-8">CHIP-8',
#  '\n<li><a href="/wiki/ChucK" title="ChucK">ChucK',
#  '\n<li><a href="/wiki/Cilk" title="Cilk">Cilk (also Cilk++ and Cilk plus)',
#  '\n<li><a href="/wiki/Claire_(programming_language)" title="Claire (programming language)">Claire',
#  '\n<li><a href="/wiki/Clarion_(programming_language)" title="Clarion (programming language)">Clarion',
#  '\n<li><a href="/wiki/Clean_(programming_language)" title="Clean (programming language)">Clean',
#  '\n<li><a href="/wiki/Clipper_(programming_language)" title="Clipper (programming language)">Clipper',
#  '\n<li><a class="mw-redirect" href="/wiki/CLIPS_(programming_language)" title="CLIPS (programming language)">CLIPS',
#  '\n<li><a href="/wiki/CLIST" title="CLIST">CLIST',
#  '\n<li><a href="/wiki/Clojure" title="Clojure">Clojure',
#  '\n<li><a href="/wiki/CLU_(programming_language)" title="CLU (programming language)">CLU',
#  '\n<li><a class="mw-redirect" href="/wiki/CMS-2_(programming_language)" title="CMS-2 (programming language)">CMS-2',
#  '\n<li><a href="/wiki/COBOL" title="COBOL">COBOL</a> – ISO/IEC 1989</li>\n<li><a href="/wiki/CobolScript" title="CobolScript">CobolScript</a> – COBOL Scripting language</li>\n<li><a href="/wiki/Cobra_(programming_language)" title="Cobra (programming language)">Cobra',
#  '\n<li><a href="/wiki/CoffeeScript" title="CoffeeScript">CoffeeScript',
#  '\n<li><a class="mw-redirect" href="/wiki/ColdFusion" title="ColdFusion">ColdFusion',
#  '\n<li><a href="/wiki/COMAL" title="COMAL">COMAL',
#  '\n<li><a href="/wiki/COMIT" title="COMIT">COMIT',
#  '\n<li><a href="/wiki/Common_Intermediate_Language" title="Common Intermediate Language">Common Intermediate Language</a> (CIL)</li>\n<li><a href="/wiki/Common_Lisp" title="Common Lisp">Common Lisp</a> (also known as CL)</li>\n<li><a href="/wiki/COMPASS" title="COMPASS">COMPASS',
#  '\n<li><a href="/wiki/Component_Pascal" title="Component Pascal">Component Pascal',
#  '\n<li><a href="/wiki/COMTRAN" title="COMTRAN">COMTRAN',
#  '\n<li><a href="/wiki/Constraint_Handling_Rules" title="Constraint Handling Rules">Constraint Handling Rules</a> (CHR)</li>\n<li><a href="/wiki/Control_Language" title="Control Language">Control Language',
#  '\n<li><a href="/wiki/Cool_(programming_language)" title="Cool (programming language)">Cool',
#  '\n<li><a href="/wiki/Coq" title="Coq">Coq',
#  '\n<li><a class="mw-redirect" href="/wiki/Coral_66" title="Coral 66">Coral 66',
#  '\n<li><a href="/wiki/CorVision" title="CorVision">CorVision',
#  '\n<li><a href="/wiki/COWSEL" title="COWSEL">COWSEL',
#  '\n<li><a href="/wiki/CPL_(programming_language)" title="CPL (programming language)">CPL',
#  '\n<li><a href="/wiki/Cryptol" title="Cryptol">Cryptol',
#  '\n<li><a href="/wiki/Crystal_(programming_language)" title="Crystal (programming language)">Crystal',
#  '\n<li><a href="/wiki/Csound" title="Csound">Csound',
#  '\n<li><a href="/wiki/Cuneiform_(programming_language)" title="Cuneiform (programming language)">Cuneiform',
#  '\n<li><a href="/wiki/Curl_(programming_language)" title="Curl (programming language)">Curl',
#  '\n<li><a href="/wiki/Curry_(programming_language)" title="Curry (programming language)">Curry',
#  '\n<li><a href="/wiki/Cybil_(programming_language)" title="Cybil (programming language)">Cybil',
#  '\n<li><a href="/wiki/Cyclone_(programming_language)" title="Cyclone (programming language)">Cyclone',
#  '\n<li><a class="mw-redirect" href="/wiki/Cypher_Query_Language" title="Cypher Query Language">Cypher Query Language',
#  '\n<li><a href="/wiki/Cython" title="Cython">Cython',
#  '\n<li><a href="/wiki/CEEMAC" title="CEEMAC">CEEMAC',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/D_(programming_language)" title="D (programming language)">D</a> (also known as dlang)</li>\n<li><a href="/wiki/Dart_(programming_language)" title="Dart (programming language)">Dart',
#  '\n<li><a href="/wiki/Darwin_(programming_language)" title="Darwin (programming language)">Darwin',
#  '\n<li><a href="/wiki/DataFlex" title="DataFlex">DataFlex',
#  '\n<li><a href="/wiki/Datalog" title="Datalog">Datalog',
#  '\n<li><a href="/wiki/DATATRIEVE" title="DATATRIEVE">DATATRIEVE',
#  '\n<li><a href="/wiki/DBase" title="DBase">dBase',
#  '\n<li><a href="/wiki/Dc_(computer_program)" title="Dc (computer program)">dc',
#  '\n<li><a href="/wiki/DIGITAL_Command_Language" title="DIGITAL Command Language">DCL (DIGITAL Command Language)',
#  '\n<li><a href="/wiki/Delphi_(software)" title="Delphi (software)">Delphi',
#  '\n<li><a href="/wiki/DIBOL" title="DIBOL">DIBOL',
#  '\n<li><a href="/wiki/Dink_Smallwood#Modification" title="Dink Smallwood">DinkC',
#  '\n<li><a class="mw-redirect" href="/wiki/Dog_(programming_language)" title="Dog (programming language)">Dog',
#  '\n<li><a href="/wiki/Draco_(programming_language)" title="Draco (programming language)">Draco',
#  '\n<li><a href="/wiki/DRAKON" title="DRAKON">DRAKON',
#  '\n<li><a href="/wiki/Dylan_(programming_language)" title="Dylan (programming language)">Dylan',
#  '\n<li><a href="/wiki/DYNAMO_(programming_language)" title="DYNAMO (programming language)">DYNAMO',
#  '\n<li><a class="mw-redirect" href="/wiki/Data_analysis_expressions" title="Data analysis expressions">DAX (Data Analysis Expressions)',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/E_(programming_language)" title="E (programming language)">E',
#  '\n<li><a href="/wiki/Ease_(programming_language)" title="Ease (programming language)">Ease',
#  '\n<li><a href="/wiki/PL/I" title="PL/I">Easy PL/I',
#  '\n<li><a href="/wiki/Easytrieve" title="Easytrieve">EASYTRIEVE PLUS',
#  '\n<li><a href="/wiki/EC_(programming_language)" title="EC (programming language)">eC',
#  '\n<li><a href="/wiki/ECMAScript" title="ECMAScript">ECMAScript',
#  '\n<li><a href="/wiki/Edinburgh_IMP" title="Edinburgh IMP">Edinburgh IMP',
#  '\n<li><a href="/wiki/EGL_(programming_language)" title="EGL (programming language)">EGL',
#  '\n<li><a href="/wiki/Eiffel_(programming_language)" title="Eiffel (programming language)">Eiffel',
#  '\n<li><a href="/wiki/ELAN_(programming_language)" title="ELAN (programming language)">ELAN',
#  '\n<li><a href="/wiki/Elixir_(programming_language)" title="Elixir (programming language)">Elixir',
#  '\n<li><a href="/wiki/Elm_(programming_language)" title="Elm (programming language)">Elm',
#  '\n<li><a href="/wiki/Emacs_Lisp" title="Emacs Lisp">Emacs Lisp',
#  '\n<li><a href="/wiki/Emerald_(programming_language)" title="Emerald (programming language)">Emerald',
#  '\n<li><a href="/wiki/Epigram_(programming_language)" title="Epigram (programming language)">Epigram',
#  '\n<li><a href="/wiki/Easy_Programming_Language" title="Easy Programming Language">EPL (Easy Programming Language)',
#  '\n<li><a href="/wiki/Erlang_(programming_language)" title="Erlang (programming language)">Erlang',
#  '\n<li><a class="mw-redirect" href="/wiki/Es_(Unix_shell)" title="Es (Unix shell)">es',
#  '\n<li><a href="/wiki/Escher_(programming_language)" title="Escher (programming language)">Escher',
#  '\n<li><a href="/wiki/Executive_Systems_Problem_Oriented_Language" title="Executive Systems Problem Oriented Language">ESPOL',
#  '\n<li><a href="/wiki/Esterel" title="Esterel">Esterel',
#  '\n<li><a href="/wiki/Etoys_(programming_language)" title="Etoys (programming language)">Etoys',
#  '\n<li><a href="/wiki/Euclid_(programming_language)" title="Euclid (programming language)">Euclid',
#  '\n<li><a href="/wiki/Euler_(programming_language)" title="Euler (programming language)">Euler',
#  '\n<li><a href="/wiki/Euphoria_(programming_language)" title="Euphoria (programming language)">Euphoria',
#  '\n<li><a href="/wiki/EusLisp_Robot_Programming_Language" title="EusLisp Robot Programming Language">EusLisp Robot Programming Language',
#  '\n<li><a href="/wiki/CMS_EXEC" title="CMS EXEC">CMS EXEC</a> (EXEC)</li>\n<li><a href="/wiki/EXEC_2" title="EXEC 2">EXEC 2',
#  '\n<li><a href="/wiki/Executable_UML" title="Executable UML">Executable UML',
#  '\n<li><a href="/wiki/Ezhil_(programming_language)" title="Ezhil (programming language)">Ezhil',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/F_(programming_language)" title="F (programming language)">F',
#  '\n<li><a href="/wiki/F_Sharp_(programming_language)" title="F Sharp (programming language)">F# (F sharp)',
#  '\n<li><a href="/wiki/F*_(programming_language)" title="F* (programming language)">F*',
#  '\n<li><a href="/wiki/Factor_(programming_language)" title="Factor (programming language)">Factor',
#  '\n<li><a href="/wiki/Fantom_(programming_language)" title="Fantom (programming language)">Fantom',
#  '\n<li><a href="/wiki/FAUST_(programming_language)" title="FAUST (programming language)">FAUST',
#  '\n<li><a class="mw-redirect" href="/wiki/FFP_(programming_language)" title="FFP (programming language)">FFP',
#  '\n<li><a class="mw-redirect" href="/wiki/Friendly_interactive_shell" title="Friendly interactive shell">fish',
#  '\n<li><a href="/wiki/Fj%C3%B6lnir_(programming_language)" title="Fjölnir (programming language)">Fjölnir',
#  '\n<li><a href="/wiki/FL_(programming_language)" title="FL (programming language)">FL',
#  '\n<li><a href="/wiki/Flavors_(programming_language)" title="Flavors (programming language)">Flavors',
#  '\n<li><a class="mw-redirect" href="/wiki/Flex_(language)" title="Flex (language)">Flex',
#  '\n<li><a href="/wiki/Flix_(programming_language)" title="Flix (programming language)">Flix',
#  '\n<li><a href="/wiki/BlooP_and_FlooP" title="BlooP and FlooP">FlooP',
#  '\n<li><a href="/wiki/FLOW-MATIC" title="FLOW-MATIC">FLOW-MATIC (B0)',
#  '\n<li><a href="/wiki/FOCAL_(programming_language)" title="FOCAL (programming language)">FOCAL (Formulating On-Line Calculations in Algebraic Language/FOrmula CALculator)',
#  '\n<li><a href="/wiki/FOCUS" title="FOCUS">FOCUS',
#  '\n<li><a href="/wiki/FOIL_(programming_language)" title="FOIL (programming language)">FOIL',
#  '\n<li><a class="mw-redirect" href="/wiki/FORMAC_(programming_language)" title="FORMAC (programming language)">FORMAC (FORMula MAnipulation Compiler)',
#  '\n<li><a href="/wiki/Formula_language" title="Formula language">@Formula',
#  '\n<li><a href="/wiki/Forth_(programming_language)" title="Forth (programming language)">Forth',
#  '\n<li><a href="/wiki/Fortran" title="Fortran">Fortran</a> – ISO/IEC 1539</li>\n<li><a href="/wiki/Fortress_(programming_language)" title="Fortress (programming language)">Fortress',
#  '\n<li><a href="/wiki/FP_(programming_language)" title="FP (programming language)">FP',
#  '\n<li><a class="mw-redirect" href="/wiki/FoxPro_(programming_language)" title="FoxPro (programming language)">FoxBase/FoxPro',
#  '\n<li><a href="/wiki/Franz_Lisp" title="Franz Lisp">Franz Lisp',
#  '\n<li><a href="/wiki/Futhark_(programming_language)" title="Futhark (programming language)">Futhark',
#  '\n<li><a href="/wiki/F-Script_(programming_language)" title="F-Script (programming language)">F-Script',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a class="mw-redirect" href="/wiki/Game_Maker_Language" title="Game Maker Language">Game Maker Language',
#  '\n<li><a href="/wiki/GameMonkey_Script" title="GameMonkey Script">GameMonkey Script',
#  '\n<li><a class="mw-redirect" href="/wiki/General_Algebraic_Modeling_System" title="General Algebraic Modeling System">GAMS (General Algebraic Modeling System)',
#  '\n<li><a class="mw-redirect" href="/wiki/GAP_computer_algebra_system" title="GAP computer algebra system">GAP',
#  '\n<li><a href="/wiki/G-code" title="G-code">G-code',
#  '\n<li><a href="/wiki/Godot_(game_engine)" title="Godot (game engine)">GDScript (Godot)',
#  '\n<li><a href="/wiki/Genie_(programming_language)" title="Genie (programming language)">Genie',
#  '\n<li><a href="/wiki/Geometric_Description_Language" title="Geometric Description Language">GDL (Geometric Description Language)',
#  '\n<li><a href="/wiki/GEORGE_(programming_language)" title="GEORGE (programming language)">GEORGE',
#  '\n<li><a href="/wiki/OpenGL_Shading_Language" title="OpenGL Shading Language">GLSL (OpenGL Shading Language)',
#  '\n<li><a href="/wiki/GNU_E" title="GNU E">GNU E',
#  '\n<li><a href="/wiki/GNU_Guile" title="GNU Guile">GNU Guile (GNU Ubiquitous Intelligent Language for Extensions)',
#  '\n<li><a href="/wiki/Go_(programming_language)" title="Go (programming language)">Go',
#  '\n<li><a href="/wiki/Go!_(programming_language)" title="Go! (programming language)">Go!',
#  '\n<li><a href="/wiki/Game_Oriented_Assembly_Lisp" title="Game Oriented Assembly Lisp">GOAL (Game Oriented Assembly Lisp)',
#  '\n<li><a href="/wiki/G%C3%B6del_(programming_language)" title="Gödel (programming language)">Gödel',
#  '\n<li><a href="/wiki/Golo_(programming_language)" title="Golo (programming language)">Golo',
#  '\n<li><a href="/wiki/MAD_(programming_language)" title="MAD (programming language)">GOM (Good Old Mad)',
#  '\n<li><a href="/wiki/Google_Apps_Script" title="Google Apps Script">Google Apps Script',
#  '\n<li><a href="/wiki/Gosu_(programming_language)" title="Gosu (programming language)">Gosu',
#  '\n<li><a href="/wiki/IBM_1620#GOTRAN" title="IBM 1620">GOTRAN (IBM 1620)',
#  '\n<li><a href="/wiki/GPSS" title="GPSS">GPSS (General Purpose Simulation System)',
#  '\n<li><a href="/wiki/Computer_Sciences_Corporation" title="Computer Sciences Corporation">GraphTalk (Computer Sciences Corporation)',
#  '\n<li><a href="/wiki/GRASS_(programming_language)" title="GRASS (programming language)">GRASS',
#  '\n<li><a href="/wiki/Grasshopper_3D" title="Grasshopper 3D">Grasshopper',
#  '\n<li><a href="/wiki/Apache_Groovy" title="Apache Groovy">Groovy (Apache Groovy)',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/Hack_(programming_language)" title="Hack (programming language)">Hack',
#  '\n<li><a class="mw-redirect" href="/wiki/HAGGIS" title="HAGGIS">HAGGIS',
#  '\n<li><a href="/wiki/HAL/S" title="HAL/S">HAL/S',
#  '\n<li><a href="/wiki/Halide_(programming_language)" title="Halide (programming language)">Halide (programming language)',
#  '\n<li><a href="/wiki/Hamilton_C_shell" title="Hamilton C shell">Hamilton C shell',
#  '\n<li><a class="mw-redirect" href="/wiki/Harbour_(software)" title="Harbour (software)">Harbour',
#  '\n<li><a class="mw-redirect" href="/wiki/Hartmann_pipeline" title="Hartmann pipeline">Hartmann pipelines',
#  '\n<li><a class="mw-redirect" href="/wiki/Haskell_(programming_language)" title="Haskell (programming language)">Haskell',
#  '\n<li><a href="/wiki/Haxe" title="Haxe">Haxe',
#  '\n<li><a href="/wiki/Hermes_(programming_language)" title="Hermes (programming language)">Hermes',
#  '\n<li><a href="/wiki/High_Level_Assembly" title="High Level Assembly">High Level Assembly (HLA)',
#  '\n<li><a class="mw-redirect" href="/wiki/High_Level_Shader_Language" title="High Level Shader Language">HLSL',
#  '\n<li><a href="/wiki/Hollywood_(programming_language)" title="Hollywood (programming language)">Hollywood',
#  '\n<li><a href="/wiki/TempleOS" title="TempleOS">HolyC (TempleOS)',
#  '\n<li><a href="/wiki/Hop_(software)" title="Hop (software)">Hop',
#  '\n<li><a href="/wiki/Hopscotch_(programming_language)" title="Hopscotch (programming language)">Hopscotch',
#  '\n<li><a href="/wiki/Hope_(programming_language)" title="Hope (programming language)">Hope',
#  '\n<li><a class="mw-redirect" href="/wiki/Hume_(language)" title="Hume (language)">Hume',
#  '\n<li><a href="/wiki/HyperTalk" title="HyperTalk">HyperTalk',
#  '\n<li><a href="/wiki/Hy" title="Hy">Hy',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/Io_(programming_language)" title="Io (programming language)">Io',
#  '\n<li><a href="/wiki/Icon_(programming_language)" title="Icon (programming language)">Icon',
#  '\n<li><a class="mw-redirect" href="/wiki/IBM_Basic_assembly_language" title="IBM Basic assembly language">IBM Basic assembly language',
#  '\n<li><a href="/wiki/IBM_HAScript" title="IBM HAScript">IBM HAScript',
#  '\n<li><a href="/wiki/IBM_Informix-4GL" title="IBM Informix-4GL">IBM Informix-4GL',
#  '\n<li><a href="/wiki/IBM_RPG" title="IBM RPG">IBM RPG',
#  '\n<li><a href="/wiki/IDL_(programming_language)" title="IDL (programming language)">IDL',
#  '\n<li><a href="/wiki/Idris_(programming_language)" title="Idris (programming language)">Idris',
#  '\n<li><a class="mw-redirect" href="/wiki/Inform_(programming_language)" title="Inform (programming language)">Inform',
#  '\n<li><a href="/wiki/ISLISP" title="ISLISP">ISLISP',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/J_(programming_language)" title="J (programming language)">J',
#  '\n<li><a class="mw-redirect" href="/wiki/J_Sharp" title="J Sharp">J# (J sharp)',
#  '\n<li><a href="/wiki/Visual_J%2B%2B" title="Visual J++">J++ (J plus plus)',
#  '\n<li><a href="/wiki/JADE_(programming_language)" title="JADE (programming language)">JADE',
#  '\n<li><a class="mw-redirect" href="/wiki/Jai_(programming_language)" title="Jai (programming language)">Jai',
#  '\n<li><a href="/wiki/JAL_(compiler)" title="JAL (compiler)">JAL',
#  '\n<li><a href="/wiki/Janus_(concurrent_constraint_programming_language)" title="Janus (concurrent constraint programming language)">Janus (concurrent constraint programming language)',
#  '\n<li><a href="/wiki/Janus_(time-reversible_computing_programming_language)" title="Janus (time-reversible computing programming language)">Janus (time-reversible computing programming language)',
#  '\n<li><a class="mw-redirect" href="/wiki/JASS_(scripting_language)" title="JASS (scripting language)">JASS',
#  '\n<li><a href="/wiki/Java_(programming_language)" title="Java (programming language)">Java',
#  '\n<li><a href="/wiki/JavaFX_Script" title="JavaFX Script">JavaFX Script',
#  '\n<li><a href="/wiki/JavaScript" title="JavaScript">JavaScript',
#  '\n<li><a href="/wiki/Jess_(programming_language)" title="Jess (programming language)">Jess',
#  '\n<li><a href="/wiki/Job_Control_Language" title="Job Control Language">JCL',
#  '\n<li><a href="/wiki/JEAN" title="JEAN">JEAN',
#  '\n<li><a href="/wiki/Join_Java" title="Join Java">Join Java',
#  '\n<li><a href="/wiki/JOSS" title="JOSS">JOSS',
#  '\n<li><a href="/wiki/Joule_(programming_language)" title="Joule (programming language)">Joule',
#  '\n<li><a href="/wiki/JOVIAL" title="JOVIAL">JOVIAL',
#  '\n<li><a href="/wiki/Joy_(programming_language)" title="Joy (programming language)">Joy',
#  '\n<li><a href="/wiki/JScript" title="JScript">JScript',
#  '\n<li><a href="/wiki/JScript_.NET" title="JScript .NET">JScript .NET',
#  '\n<li><a href="/wiki/Julia_(programming_language)" title="Julia (programming language)">Julia',
#  '\n<li><a href="/wiki/Jython" title="Jython">Jython',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/K_(programming_language)" title="K (programming language)">K',
#  '\n<li><a href="/wiki/Kaleidoscope_(programming_language)" title="Kaleidoscope (programming language)">Kaleidoscope',
#  '\n<li><a href="/wiki/Karel_(programming_language)" title="Karel (programming language)">Karel',
#  '\n<li><a class="mw-redirect" href="/wiki/IntelliCorp_(Software)" title="IntelliCorp (Software)">KEE',
#  '\n<li><a href="/wiki/KiXtart" title="KiXtart">Kixtart',
#  '\n<li><a class="mw-redirect" href="/wiki/Klerer-May_System" title="Klerer-May System">Klerer-May System',
#  '\n<li><a href="/wiki/Knowledge_Interchange_Format" title="Knowledge Interchange Format">KIF (Knowledge Interchange Format)',
#  '\n<li><a class="mw-redirect" href="/wiki/Kojo_(programming_language)" title="Kojo (programming language)">Kojo',
#  '\n<li><a href="/wiki/Kotlin_(programming_language)" title="Kotlin (programming language)">Kotlin',
#  '\n<li><a href="/wiki/Kent_Recursive_Calculator" title="Kent Recursive Calculator">KRC',
#  '\n<li><a href="/wiki/KRL_(programming_language)" title="KRL (programming language)">KRL',
#  '\n<li>KRL (<a href="/wiki/KUKA_Robot_Language" title="KUKA Robot Language">KUKA Robot Language</a>)</li>\n<li><a class="mw-redirect" href="/wiki/KRYPTON" title="KRYPTON">KRYPTON',
#  '\n<li><a href="/wiki/KornShell" title="KornShell">KornShell (ksh)',
#  '\n<li><a href="/wiki/Kodu_Game_Lab" title="Kodu Game Lab">Kodu',
#  '\n<li><a href="/wiki/Kivy_(framework)#Kv_language" title="Kivy (framework)">Kv (Kivy)',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/LabVIEW" title="LabVIEW">LabVIEW',
#  '\n<li><a href="/wiki/Ladder_logic" title="Ladder logic">Ladder',
#  '\n<li><a href="/wiki/LANSA_(development_environment)" title="LANSA (development environment)">LANSA',
#  '\n<li><a href="/wiki/Lasso_(programming_language)" title="Lasso (programming language)">Lasso',
#  '\n<li><a href="/wiki/Lava_(programming_language)" title="Lava (programming language)">Lava',
#  '\n<li><a href="/wiki/Little_Computer_3" title="Little Computer 3">LC-3',
#  '\n<li><a href="/wiki/Lean_(proof_assistant)" title="Lean (proof assistant)">Lean',
#  '\n<li><a class="mw-redirect" href="/wiki/Legoscript" title="Legoscript">Legoscript',
#  '\n<li><a href="/wiki/Little_Implementation_Language" title="Little Implementation Language">LIL',
#  '\n<li><a href="/wiki/LilyPond" title="LilyPond">LilyPond',
#  '\n<li><a href="/wiki/Limbo_(programming_language)" title="Limbo (programming language)">Limbo',
#  '\n<li><a href="/wiki/Limnor" title="Limnor">Limnor',
#  '\n<li><a href="/wiki/LINC_4GL" title="LINC 4GL">LINC',
#  '\n<li><a href="/wiki/Lingo_(programming_language)" title="Lingo (programming language)">Lingo',
#  '\n<li><a class="mw-redirect" href="/wiki/LINQ" title="LINQ">LINQ',
#  '\n<li><a href="/wiki/LIS_(programming_language)" title="LIS (programming language)">LIS',
#  '\n<li><a href="/wiki/Language_for_Instruction_Set_Architecture" title="Language for Instruction Set Architecture">LISA',
#  '\n<li><a href="/wiki/Language_H" title="Language H">Language H',
#  '\n<li><a href="/wiki/Lisp_(programming_language)" title="Lisp (programming language)">Lisp</a> – ISO/IEC 13816</li>\n<li><a href="/wiki/Lite-C" title="Lite-C">Lite-C',
#  '\n<li><a class="mw-redirect" href="/wiki/Lithe_(programming_language)" title="Lithe (programming language)">Lithe',
#  '\n<li><a href="/wiki/Little_b_(programming_language)" title="Little b (programming language)">Little b',
#  '\n<li><a href="/wiki/Ethereum#Contract_source_code" title="Ethereum">LLL',
#  '\n<li><a href="/wiki/Logo_(programming_language)" title="Logo (programming language)">Logo',
#  '\n<li><a href="/wiki/Logtalk" title="Logtalk">Logtalk',
#  '\n<li><a href="/wiki/LotusScript" title="LotusScript">LotusScript',
#  '\n<li><a class="mw-redirect" href="/wiki/LPC_(programming_language)" title="LPC (programming language)">LPC',
#  '\n<li><a href="/wiki/LSE_(programming_language)" title="LSE (programming language)">LSE',
#  '\n<li><a class="mw-redirect" href="/wiki/Linden_Scripting_Language" title="Linden Scripting Language">LSL',
#  '\n<li><a href="/wiki/LiveCode" title="LiveCode">LiveCode',
#  '\n<li><a href="/wiki/LiveScript_(programming_language)" title="LiveScript (programming language)">LiveScript',
#  '\n<li><a href="/wiki/Lua_(programming_language)" title="Lua (programming language)">Lua',
#  '\n<li><a href="/wiki/Lucid_(programming_language)" title="Lucid (programming language)">Lucid',
#  '\n<li><a href="/wiki/Lustre_(programming_language)" title="Lustre (programming language)">Lustre',
#  '\n<li><a href="/wiki/LYaPAS" title="LYaPAS">LYaPAS',
#  '\n<li><a href="/wiki/Lynx_(programming_language)" title="Lynx (programming language)">Lynx',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a class="mw-redirect" href="/wiki/M_Formula_language" title="M Formula language">M Formula language',
#  '\n<li><a href="/wiki/M2001" title="M2001">M2001',
#  '\n<li><a href="/wiki/M4_(computer_language)" title="M4 (computer language)">M4',
#  '\n<li><a class="mw-redirect" href="/wiki/M_Sharp_(programming_language)" title="M Sharp (programming language)">M#',
#  '\n<li><a href="/wiki/Machine_code" title="Machine code">Machine code',
#  '\n<li><a href="/wiki/MAD_(programming_language)" title="MAD (programming language)">MAD</a> (Michigan Algorithm Decoder)</li>\n<li><a href="/wiki/MAD_(programming_language)" title="MAD (programming language)">MAD/I',
#  '\n<li><a href="/wiki/Magik_(programming_language)" title="Magik (programming language)">Magik',
#  '\n<li><a class="mw-redirect" href="/wiki/Magma_computer_algebra_system" title="Magma computer algebra system">Magma',
#  '\n<li><a href="/wiki/M%C3%A1ni" title="Máni">Máni',
#  '\n<li><a href="/wiki/Maple_(software)" title="Maple (software)">Maple',
#  '\n<li><a href="/wiki/MAPPER" title="MAPPER">MAPPER</a> (now part of BIS)</li>\n<li><a href="/wiki/MARK_IV_(software)" title="MARK IV (software)">MARK-IV</a> (now VISION:BUILDER)</li>\n<li><a href="/wiki/Mary_(programming_language)" title="Mary (programming language)">Mary',
#  '\n<li><a href="/wiki/MATLAB" title="MATLAB">MATLAB',
#  '\n<li><a href="/wiki/Microsoft_Macro_Assembler" title="Microsoft Macro Assembler">MASM Microsoft Assembly x86',
#  '\n<li><a href="/wiki/MATH-MATIC" title="MATH-MATIC">MATH-MATIC',
#  '\n<li><a href="/wiki/Maude_system" title="Maude system">Maude system',
#  '\n<li><a href="/wiki/Maxima_(software)" title="Maxima (software)">Maxima</a> (see also <a href="/wiki/Macsyma" title="Macsyma">Macsyma</a>)</li>\n<li><a href="/wiki/Max_(software)" title="Max (software)">Max</a> (Max Msp – Graphical Programming Environment)</li>\n<li><a href="/wiki/Autodesk_3ds_Max" title="Autodesk 3ds Max">MaxScript</a> internal language 3D Studio Max</li>\n<li><a href="/wiki/Maya_Embedded_Language" title="Maya Embedded Language">Maya (MEL)',
#  '\n<li><a href="/wiki/MDL_(programming_language)" title="MDL (programming language)">MDL',
#  '\n<li><a href="/wiki/Mercury_(programming_language)" title="Mercury (programming language)">Mercury',
#  '\n<li><a href="/wiki/Mesa_(programming_language)" title="Mesa (programming language)">Mesa',
#  '\n<li><a href="/wiki/MHEG-5" title="MHEG-5">MHEG-5 (Interactive TV programming language)',
#  '\n<li><a href="/wiki/Microassembler" title="Microassembler">Microcode',
#  '\n<li><a href="/wiki/Microsoft_Power_Fx" title="Microsoft Power Fx">Microsoft Power Fx',
#  '\n<li><a href="/wiki/MIIS_(programming_language)" title="MIIS (programming language)">MIIS',
#  '\n<li><a href="/wiki/Milk_(programming_language)" title="Milk (programming language)">Milk (programming language)',
#  '\n<li><a href="/wiki/MIMIC" title="MIMIC">MIMIC',
#  '\n<li><a href="/wiki/Mirah_(programming_language)" title="Mirah (programming language)">Mirah',
#  '\n<li><a href="/wiki/Miranda_(programming_language)" title="Miranda (programming language)">Miranda',
#  '\n<li><a href="/wiki/MIVA_Script" title="MIVA Script">MIVA Script',
#  '\n<li><a href="/wiki/ML_(programming_language)" title="ML (programming language)">ML',
#  '\n<li><a href="/wiki/Model_204" title="Model 204">Model 204',
#  '\n<li><a href="/wiki/Modelica" title="Modelica">Modelica',
#  '\n<li><a href="/wiki/Malbolge" title="Malbolge">Malbolge',
#  '\n<li><a href="/wiki/Modula" title="Modula">Modula',
#  '\n<li><a href="/wiki/Modula-2" title="Modula-2">Modula-2',
#  '\n<li><a href="/wiki/Modula-3" title="Modula-3">Modula-3',
#  '\n<li><a class="mw-redirect" href="/wiki/Mohol_programming_languages" title="Mohol programming languages">Mohol',
#  '\n<li><a class="mw-redirect" href="/wiki/MOO_(programming_language)" title="MOO (programming language)">MOO',
#  '\n<li><a href="/wiki/Mortran" title="Mortran">Mortran',
#  '\n<li><a href="/wiki/Mouse_(programming_language)" title="Mouse (programming language)">Mouse',
#  '\n<li><a href="/wiki/MPD_(programming_language)" title="MPD (programming language)">MPD',
#  '\n<li><a href="/wiki/MIRC_scripting_language" title="MIRC scripting language">MSL',
#  '\n<li><a href="/wiki/MUMPS" title="MUMPS">MUMPS',
#  '\n<li><a href="/wiki/MuPAD" title="MuPAD">MuPAD',
#  '\n<li><a href="/wiki/Ethereum#Programming_languages" title="Ethereum">Mutan',
#  '\n<li><a href="/wiki/Mystic_BBS" title="Mystic BBS">Mystic Programming Language</a> (MPL)</li></ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/Netwide_Assembler" title="Netwide Assembler">NASM',
#  '\n<li><a href="/wiki/Napier88" title="Napier88">Napier88',
#  '\n<li><a class="mw-redirect" href="/wiki/Neko_(programming_language)" title="Neko (programming language)">Neko',
#  '\n<li><a href="/wiki/Nemerle" title="Nemerle">Nemerle',
#  '\n<li><a href="/wiki/NESL" title="NESL">NESL',
#  '\n<li><a href="/wiki/Net.Data" title="Net.Data">Net.Data',
#  '\n<li><a href="/wiki/NetLogo" title="NetLogo">NetLogo',
#  '\n<li><a href="/wiki/NetRexx" title="NetRexx">NetRexx',
#  '\n<li><a href="/wiki/NewLISP" title="NewLISP">NewLISP',
#  '\n<li><a href="/wiki/NEWP" title="NEWP">NEWP',
#  '\n<li><a href="/wiki/Newspeak_(programming_language)" title="Newspeak (programming language)">Newspeak',
#  '\n<li><a href="/wiki/NewtonScript" title="NewtonScript">NewtonScript',
#  '\n<li><a href="/wiki/Nial" title="Nial">Nial',
#  '\n<li><a class="mw-redirect" href="/wiki/Nickle_(programming_language)" title="Nickle (programming language)">Nickle</a> (<a class="mw-redirect" href="/wiki/Nickle_(programming_language)" title="Nickle (programming language)">NITIN</a>)</li>\n<li><a href="/wiki/Nim_(programming_language)" title="Nim (programming language)">Nim',
#  '\n<li><a class="mw-redirect" href="/wiki/Nix_package_manager" title="Nix package manager">Nix (Systems configuration language)',
#  '\n<li><a class="mw-redirect" href="/wiki/NORD_Programming_Language" title="NORD Programming Language">NPL',
#  '\n<li><a href="/wiki/Not_eXactly_C" title="Not eXactly C">Not eXactly C</a> (NXC)</li>\n<li><a href="/wiki/Not_Quite_C" title="Not Quite C">Not Quite C</a> (NQC)</li>\n<li><a href="/wiki/Nullsoft_Scriptable_Install_System" title="Nullsoft Scriptable Install System">NSIS',
#  '\n<li><a href="/wiki/Nu_(programming_language)" title="Nu (programming language)">Nu',
#  '\n<li><a href="/wiki/NWScript" title="NWScript">NWScript',
#  '\n<li><a class="mw-redirect" href="/wiki/NXT-G" title="NXT-G">NXT-G',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/O:XML" title="O:XML">o:XML',
#  '\n<li><a href="/wiki/Oak_(programming_language)" title="Oak (programming language)">Oak',
#  '\n<li><a href="/wiki/Oberon_(programming_language)" title="Oberon (programming language)">Oberon',
#  '\n<li><a class="mw-redirect" href="/wiki/OBJ2" title="OBJ2">OBJ2',
#  '\n<li><a href="/wiki/Object_Lisp" title="Object Lisp">Object Lisp',
#  '\n<li><a class="mw-redirect" href="/wiki/ObjectLOGO" title="ObjectLOGO">ObjectLOGO',
#  '\n<li><a href="/wiki/Object_REXX" title="Object REXX">Object REXX',
#  '\n<li><a href="/wiki/Object_Pascal" title="Object Pascal">Object Pascal',
#  '\n<li><a href="/wiki/Objective-C" title="Objective-C">Objective-C',
#  '\n<li><a href="/wiki/Obliq" title="Obliq">Obliq',
#  '\n<li><a href="/wiki/OCaml" title="OCaml">OCaml',
#  '\n<li><a href="/wiki/Occam_(programming_language)" title="Occam (programming language)">occam',
#  '\n<li><a href="/wiki/Occam-%CF%80" title="Occam-π">occam-π',
#  '\n<li><a href="/wiki/GNU_Octave" title="GNU Octave">Octave',
#  '\n<li><a href="/wiki/OmniMark" title="OmniMark">OmniMark',
#  '\n<li><a href="/wiki/Opa_(programming_language)" title="Opa (programming language)">Opa',
#  '\n<li><a href="/wiki/Opal_(programming_language)" title="Opal (programming language)">Opal',
#  '\n<li><a href="/wiki/Open_Programming_Language" title="Open Programming Language">Open Programming Language</a> (OPL)</li>\n<li><a href="/wiki/OpenCL" title="OpenCL">OpenCL',
#  '\n<li><a href="/wiki/OpenEdge_Advanced_Business_Language" title="OpenEdge Advanced Business Language">OpenEdge Advanced Business Language</a> (ABL)</li>\n<li><a href="/wiki/OpenVera" title="OpenVera">OpenVera',
#  '\n<li><a href="/wiki/OpenQASM" title="OpenQASM">OpenQASM',
#  '\n<li><a href="/wiki/OPS5" title="OPS5">OPS5',
#  '\n<li><a href="/wiki/OptimJ" title="OptimJ">OptimJ',
#  '\n<li><a href="/wiki/Orc_(programming_language)" title="Orc (programming language)">Orc',
#  '\n<li><a href="/wiki/ORCA/Modula-2" title="ORCA/Modula-2">ORCA/Modula-2',
#  '\n<li><a href="/wiki/Oriel_(scripting_language)" title="Oriel (scripting language)">Oriel',
#  '\n<li><a href="/wiki/Orwell_(programming_language)" title="Orwell (programming language)">Orwell',
#  '\n<li><a href="/wiki/Oxygene_(programming_language)" title="Oxygene (programming language)">Oxygene',
#  '\n<li><a href="/wiki/Oz_(programming_language)" title="Oz (programming language)">Oz',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/P_(programming_language)" title="P (programming language)">P',
#  '\n<li><a href="/wiki/P4_(programming_language)" title="P4 (programming language)">P4',
#  '\n<li><a href="/wiki/P%E2%80%B2%E2%80%B2" title="P′′">P′′',
#  '\n<li><a href="/wiki/ParaSail_(programming_language)" title="ParaSail (programming language)">ParaSail',
#  '\n<li><a href="/wiki/PARI/GP" title="PARI/GP">PARI/GP',
#  '\n<li><a href="/wiki/Pascal_(programming_language)" title="Pascal (programming language)">Pascal</a> – ISO 7185</li>\n<li><a href="/wiki/Pascal_Script" title="Pascal Script">Pascal Script',
#  '\n<li><a href="/wiki/PCASTL" title="PCASTL">PCASTL',
#  '\n<li><a class="mw-redirect" href="/wiki/Programming_language_for_Computable_Functions" title="Programming language for Computable Functions">PCF',
#  '\n<li><a href="/wiki/PEARL_(programming_language)" title="PEARL (programming language)">PEARL',
#  '\n<li><a href="/wiki/PeopleCode" title="PeopleCode">PeopleCode',
#  '\n<li><a href="/wiki/Perl" title="Perl">Perl',
#  '\n<li><a href="/wiki/Perl_Data_Language" title="Perl Data Language">PDL',
#  '\n<li><a href="/wiki/Pharo" title="Pharo">Pharo',
#  '\n<li><a href="/wiki/PHP" title="PHP">PHP',
#  '\n<li><a href="/wiki/Pico_(programming_language)" title="Pico (programming language)">Pico',
#  '\n<li><a class="mw-redirect" href="/wiki/Picolisp" title="Picolisp">Picolisp',
#  '\n<li><a href="/wiki/Pict_(programming_language)" title="Pict (programming language)">Pict',
#  '\n<li><a class="mw-redirect" href="/wiki/Pike_(programming_language)" title="Pike (programming language)">Pike',
#  '\n<li><a href="/wiki/PILOT" title="PILOT">PILOT',
#  '\n<li><a class="mw-redirect" href="/wiki/Hartmann_pipeline" title="Hartmann pipeline">Pipelines',
#  '\n<li><a href="/wiki/Pizza_(programming_language)" title="Pizza (programming language)">Pizza',
#  '\n<li><a href="/wiki/PL-11" title="PL-11">PL-11',
#  '\n<li><a href="/wiki/PL/0" title="PL/0">PL/0',
#  '\n<li><a href="/wiki/Programming_Language_for_Business" title="Programming Language for Business">PL/B',
#  '\n<li><a href="/wiki/PL/C" title="PL/C">PL/C',
#  '\n<li><a href="/wiki/PL/I" title="PL/I">PL/I</a> – ISO 6160</li>\n<li><a href="/wiki/PL/M" title="PL/M">PL/M',
#  '\n<li><a href="/wiki/PL/P" title="PL/P">PL/P',
#  '\n<li><a class="mw-redirect" href="/wiki/PL/S" title="PL/S">PL/S',
#  '\n<li><a href="/wiki/PL/SQL" title="PL/SQL">PL/SQL',
#  '\n<li><a href="/wiki/PL360" title="PL360">PL360',
#  '\n<li><a href="/wiki/PLANC" title="PLANC">PLANC',
#  '\n<li><a href="/wiki/Plankalk%C3%BCl" title="Plankalkül">Plankalkül',
#  '\n<li><a href="/wiki/Planner_(programming_language)" title="Planner (programming language)">Planner',
#  '\n<li><a href="/wiki/PLEX_(programming_language)" title="PLEX (programming language)">PLEX',
#  '\n<li><a href="/wiki/PLEXIL" title="PLEXIL">PLEXIL',
#  '\n<li><a href="/wiki/Plus_(programming_language)" title="Plus (programming language)">Plus',
#  '\n<li><a href="/wiki/POP-11" title="POP-11">POP-11',
#  '\n<li><a href="/wiki/POP-2" title="POP-2">POP-2',
#  '\n<li><a href="/wiki/PostScript" title="PostScript">PostScript',
#  '\n<li><a href="/wiki/Amiga_E#PortablE" title="Amiga E">PortablE',
#  '\n<li><a href="/wiki/POV-Ray" title="POV-Ray">POV-Ray SDL',
#  '\n<li><a class="mw-redirect" href="/wiki/Powerhouse_(programming_language)" title="Powerhouse (programming language)">Powerhouse',
#  '\n<li><a href="/wiki/PowerBuilder" title="PowerBuilder">PowerBuilder</a> – 4GL GUI application generator from Sybase</li>\n<li><a href="/wiki/PowerShell" title="PowerShell">PowerShell',
#  '\n<li><a href="/wiki/Polymorphic_Programming_Language" title="Polymorphic Programming Language">PPL',
#  '\n<li><a class="mw-redirect" href="/wiki/Processing_(programming_language)" title="Processing (programming language)">Processing',
#  '\n<li><a class="mw-redirect" href="/wiki/Processing.js" title="Processing.js">Processing.js',
#  '\n<li><a href="/wiki/Prograph" title="Prograph">Prograph',
#  '\n<li><a href="/wiki/Project_Verona" title="Project Verona">Project Verona',
#  '\n<li><a href="/wiki/Prolog" title="Prolog">Prolog',
#  '\n<li><a href="/wiki/PROMAL" title="PROMAL">PROMAL',
#  '\n<li><a href="/wiki/Promela" title="Promela">Promela',
#  '\n<li><a href="/wiki/PROSE_modeling_language" title="PROSE modeling language">PROSE modeling language',
#  '\n<li><a href="/wiki/Protel" title="Protel">PROTEL',
#  '\n<li><a href="/wiki/ProvideX" title="ProvideX">ProvideX',
#  '\n<li><a href="/wiki/Pro*C" title="Pro*C">Pro*C',
#  '\n<li><a href="/wiki/Pure_(programming_language)" title="Pure (programming language)">Pure',
#  '\n<li><a href="/wiki/Pure_Data" title="Pure Data">Pure Data',
#  '\n<li><a href="/wiki/PureScript" title="PureScript">PureScript',
#  '\n<li><a href="/wiki/PWCT" title="PWCT">PWCT',
#  '\n<li><a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/Q_(programming_language_from_Kx_Systems)" title="Q (programming language from Kx Systems)">Q (programming language from Kx Systems)',
#  '\n<li><a href="/wiki/Q_Sharp" title="Q Sharp">Q#',
#  '\n<li><a href="/wiki/Qalb_(programming_language)" title="Qalb (programming language)">Qalb',
#  '\n<li><a href="/wiki/Quantum_Computation_Language" title="Quantum Computation Language">Quantum Computation Language',
#  '\n<li><a href="/wiki/QtScript" title="QtScript">QtScript',
#  '\n<li><a href="/wiki/QuakeC" title="QuakeC">QuakeC',
#  '\n<li><a href="/wiki/Quantum_programming" title="Quantum programming">QPL',
#  '\n<li><a href="/wiki/.QL" title=".QL">.QL',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/R_(programming_language)" title="R (programming language)">R',
#  '\n<li><a href="/wiki/R%2B%2B" title="R++">R++',
#  '\n<li><a href="/wiki/Racket_(programming_language)" title="Racket (programming language)">Racket',
#  '\n<li><a href="/wiki/Raku_(programming_language)" title="Raku (programming language)">Raku',
#  '\n<li><a href="/wiki/RAPID" title="RAPID">RAPID',
#  '\n<li><a href="/wiki/Rapira" title="Rapira">Rapira',
#  '\n<li><a class="mw-redirect" href="/wiki/Ratfiv" title="Ratfiv">Ratfiv',
#  '\n<li><a href="/wiki/Ratfor" title="Ratfor">Ratfor',
#  '\n<li><a href="/wiki/Rc" title="Rc">rc',
#  '\n<li><a href="/wiki/Reason_(programming_language)" title="Reason (programming language)">Reason',
#  '\n<li><a class="mw-redirect" href="/wiki/REBOL" title="REBOL">REBOL',
#  '\n<li><a href="/wiki/Red_(programming_language)" title="Red (programming language)">Red',
#  '\n<li><a href="/wiki/Core_War" title="Core War">Redcode',
#  '\n<li><a class="mw-redirect" href="/wiki/REFAL" title="REFAL">REFAL',
#  '\n<li><a class="mw-redirect" href="/wiki/REXX" title="REXX">REXX',
#  '\n<li><a href="/wiki/Ring_(programming_language)" title="Ring (programming language)">Ring',
#  '\n<li><a href="/wiki/ROOP_(programming_language)" title="ROOP (programming language)">ROOP',
#  '\n<li><a href="/wiki/IBM_RPG" title="IBM RPG">RPG',
#  '\n<li><a href="/wiki/RPL_(programming_language)" title="RPL (programming language)">RPL',
#  '\n<li><a href="/wiki/Robot_Battle#Robot_scripting_language" title="Robot Battle">RSL',
#  '\n<li><a href="/wiki/RTL/2" title="RTL/2">RTL/2',
#  '\n<li><a href="/wiki/Ruby_(programming_language)" title="Ruby (programming language)">Ruby',
#  '\n<li><a href="/wiki/Rust_(programming_language)" title="Rust (programming language)">Rust',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/S_(programming_language)" title="S (programming language)">S',
#  '\n<li><a class="mw-redirect" href="/wiki/S2_(programming_language)" title="S2 (programming language)">S2',
#  '\n<li><a href="/wiki/S3_(programming_language)" title="S3 (programming language)">S3',
#  '\n<li><a class="mw-redirect" href="/wiki/S-Lang_(programming_language)" title="S-Lang (programming language)">S-Lang',
#  '\n<li><a href="/wiki/S-PLUS" title="S-PLUS">S-PLUS',
#  '\n<li><a href="/wiki/SA-C_(programming_language)" title="SA-C (programming language)">SA-C',
#  '\n<li><a href="/wiki/SabreTalk" title="SabreTalk">SabreTalk',
#  '\n<li><a href="/wiki/SAIL_(programming_language)" title="SAIL (programming language)">SAIL',
#  '\n<li><a href="/wiki/SAKO_(programming_language)" title="SAKO (programming language)">SAKO',
#  '\n<li><a class="mw-redirect" href="/wiki/SAS_System" title="SAS System">SAS',
#  '\n<li><a href="/wiki/SASL_(programming_language)" title="SASL (programming language)">SASL',
#  '\n<li><a href="/wiki/Sather" title="Sather">Sather',
#  '\n<li><a href="/wiki/Sawzall_(programming_language)" title="Sawzall (programming language)">Sawzall',
#  '\n<li><a href="/wiki/Scala_(programming_language)" title="Scala (programming language)">Scala',
#  '\n<li><a href="/wiki/Scheme_(programming_language)" title="Scheme (programming language)">Scheme',
#  '\n<li><a href="/wiki/Scilab" title="Scilab">Scilab',
#  '\n<li><a href="/wiki/Scratch_(programming_language)" title="Scratch (programming language)">Scratch',
#  '\n<li><a href="/wiki/Script.NET" title="Script.NET">Script.NET',
#  '\n<li><a href="/wiki/Sed" title="Sed">Sed',
#  '\n<li><a href="/wiki/Seed7" title="Seed7">Seed7',
#  '\n<li><a href="/wiki/Self_(programming_language)" title="Self (programming language)">Self',
#  '\n<li><a href="/wiki/SenseTalk" title="SenseTalk">SenseTalk',
#  '\n<li><a href="/wiki/SequenceL" title="SequenceL">SequenceL',
#  '\n<li><a href="/wiki/Ethereum#Programming_languages" title="Ethereum">Serpent',
#  '\n<li><a href="/wiki/SETL" title="SETL">SETL',
#  '\n<li><a href="/wiki/Short_Code_(computer_language)" title="Short Code (computer language)">Short Code',
#  '\n<li><a class="mw-redirect" href="/wiki/Superbase_database#History" title="Superbase database">SIMPOL',
#  '\n<li><a href="/wiki/SIGNAL_(programming_language)" title="SIGNAL (programming language)">SIGNAL',
#  '\n<li><a href="/wiki/SiMPLE" title="SiMPLE">SiMPLE',
#  '\n<li><a href="/wiki/SIMSCRIPT" title="SIMSCRIPT">SIMSCRIPT',
#  '\n<li><a href="/wiki/Simula" title="Simula">Simula',
#  '\n<li><a href="/wiki/Simulink" title="Simulink">Simulink',
#  '\n<li><a href="/wiki/SISAL" title="SISAL">SISAL',
#  '\n<li><a class="mw-redirect" href="/wiki/SKILL" title="SKILL">SKILL',
#  '\n<li><a href="/wiki/SLIP_(programming_language)" title="SLIP (programming language)">SLIP',
#  '\n<li><a href="/wiki/SMALL" title="SMALL">SMALL',
#  '\n<li><a href="/wiki/Smalltalk" title="Smalltalk">Smalltalk',
#  '\n<li><a href="/wiki/Standard_ML" title="Standard ML">SML',
#  '\n<li><a href="/wiki/Strongtalk" title="Strongtalk">Strongtalk',
#  '\n<li><a href="/wiki/Snap!_(programming_language)" title="Snap! (programming language)">Snap!',
#  '\n<li><a href="/wiki/SNOBOL" title="SNOBOL">SNOBOL</a> (<a class="mw-redirect" href="/wiki/SPITBOL_compiler" title="SPITBOL compiler">SPITBOL</a>)</li>\n<li><a class="mw-redirect" href="/wiki/Snowball_programming_language" title="Snowball programming language">Snowball',
#  '\n<li><a href="/wiki/Secure_Operations_Language" title="Secure Operations Language">SOL',
#  '\n<li><a href="/wiki/Solidity" title="Solidity">Solidity',
#  '\n<li><a href="/wiki/SOPHAEROS" title="SOPHAEROS">SOPHAEROS',
#  '\n<li><a href="/wiki/Source_(programming_language)" title="Source (programming language)">Source',
#  '\n<li><a href="/wiki/SPARK_(programming_language)" title="SPARK (programming language)">SPARK',
#  '\n<li><a href="/wiki/Speakeasy_(computational_environment)" title="Speakeasy (computational environment)">Speakeasy',
#  '\n<li><a href="/wiki/Speedcoding" title="Speedcoding">Speedcode',
#  '\n<li><a href="/wiki/Parallax_Propeller" title="Parallax Propeller">SPIN',
#  '\n<li><a href="/wiki/SP/k" title="SP/k">SP/k',
#  '\n<li><a href="/wiki/IBM_1401_Symbolic_Programming_System" title="IBM 1401 Symbolic Programming System">SPS',
#  '\n<li><a href="/wiki/SQL" title="SQL">SQL',
#  '\n<li><a href="/wiki/SQR" title="SQR">SQR',
#  '\n<li><a href="/wiki/Squeak" title="Squeak">Squeak',
#  '\n<li><a href="/wiki/Squirrel_(programming_language)" title="Squirrel (programming language)">Squirrel',
#  '\n<li><a href="/wiki/SR_(programming_language)" title="SR (programming language)">SR',
#  '\n<li><a href="/wiki/S/SL_programming_language" title="S/SL programming language">S/SL',
#  '\n<li><a class="mw-redirect" href="/wiki/Starlogo" title="Starlogo">Starlogo',
#  '\n<li><a href="/wiki/Strand_(programming_language)" title="Strand (programming language)">Strand',
#  '\n<li><a href="/wiki/Stata" title="Stata">Stata',
#  '\n<li><a href="/wiki/Stateflow" title="Stateflow">Stateflow',
#  '\n<li><a href="/wiki/Subtext_(programming_language)" title="Subtext (programming language)">Subtext',
#  '\n<li><a class="mw-redirect" href="/wiki/Superbase_database" title="Superbase database">SBL',
#  '\n<li><a href="/wiki/SuperCollider" title="SuperCollider">SuperCollider',
#  '\n<li><a href="/wiki/Superplan" title="Superplan">Superplan',
#  '\n<li><a href="/wiki/SuperTalk" title="SuperTalk">SuperTalk',
#  '\n<li><a href="/wiki/Swift_(programming_language)" title="Swift (programming language)">Swift (Apple programming language)',
#  '\n<li><a href="/wiki/Swift_(parallel_scripting_language)" title="Swift (parallel scripting language)">Swift (parallel scripting language)',
#  '\n<li><a href="/wiki/SYMPL" title="SYMPL">SYMPL',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/T_(programming_language)" title="T (programming language)">T',
#  '\n<li><a href="/wiki/TACL" title="TACL">TACL',
#  '\n<li><a href="/wiki/TACPOL_(programming_language)" title="TACPOL (programming language)">TACPOL',
#  '\n<li><a href="/wiki/TADS" title="TADS">TADS (Text Adventure Development System)',
#  '\n<li><a href="/wiki/Transaction_Application_Language" title="Transaction Application Language">TAL',
#  '\n<li><a href="/wiki/Tcl" title="Tcl">Tcl',
#  '\n<li><a href="/wiki/Tea_(programming_language)" title="Tea (programming language)">Tea',
#  '\n<li><a class="mw-redirect" href="/wiki/Text_Editor_and_Corrector" title="Text Editor and Corrector">TECO (Text Editor and Corrector)',
#  '\n<li><a href="/wiki/TELCOMP" title="TELCOMP">TELCOMP',
#  '\n<li><a href="/wiki/TeX" title="TeX">TeX',
#  '\n<li><a href="/wiki/Text_Executive_Programming_Language" title="Text Executive Programming Language">TEX (Text Executive Programming Language)',
#  '\n<li><a href="/wiki/Tensilica_Instruction_Extension" title="Tensilica Instruction Extension">TIE',
#  '\n<li><a href="/wiki/TMG_(language)" title="TMG (language)">TMG (TransMoGrifier)</a>, compiler-compiler</li>\n<li><a href="/wiki/Tom_(pattern_matching_language)" title="Tom (pattern matching language)">Tom',
#  '\n<li><a href="/wiki/Toi_(programming_language)" title="Toi (programming language)">Toi',
#  '\n<li><a href="/wiki/Clarion_(programming_language)" title="Clarion (programming language)">Topspeed (Clarion)',
#  '\n<li><a class="mw-redirect" href="/wiki/Text_Processing_Utility" title="Text Processing Utility">TPU (Text Processing Utility)',
#  '\n<li><a href="/wiki/TRAC_(programming_language)" title="TRAC (programming language)">Trac',
#  '\n<li><a href="/wiki/TTM_(programming_language)" title="TTM (programming language)">TTM',
#  '\n<li><a href="/wiki/Transact-SQL" title="Transact-SQL">T-SQL (Transact-SQL)',
#  '\n<li><a class="mw-redirect" href="/wiki/Transcript_(programming_language)" title="Transcript (programming language)">Transcript (LiveCode)',
#  '\n<li><a href="/wiki/TTCN" title="TTCN">TTCN (Tree and Tabular Combined Notation)',
#  '\n<li><a href="/wiki/Turing_(programming_language)" title="Turing (programming language)">Turing',
#  '\n<li><a class="mw-redirect" href="/wiki/TUTOR_(programming_language)" title="TUTOR (programming language)">TUTOR (PLATO Author Language)',
#  '\n<li><a href="/wiki/TXL_(programming_language)" title="TXL (programming language)">TXL',
#  '\n<li><a href="/wiki/TypeScript" title="TypeScript">TypeScript',
#  '\n<li><a href="/wiki/Tynker" title="Tynker">Tynker',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/Ubercode" title="Ubercode">Ubercode',
#  '\n<li><a href="/wiki/UCSD_Pascal" title="UCSD Pascal">UCSD Pascal',
#  '\n<li><a href="/wiki/Umple" title="Umple">Umple',
#  '\n<li><a href="/wiki/Unicon_(programming_language)" title="Unicon (programming language)">Unicon',
#  '\n<li><a href="/wiki/Uniface_(programming_language)" title="Uniface (programming language)">Uniface',
#  '\n<li><a href="/wiki/UNITY_(programming_language)" title="UNITY (programming language)">UNITY',
#  '\n<li><a class="mw-redirect" href="/wiki/UnrealScript" title="UnrealScript">UnrealScript',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/Vala_(programming_language)" title="Vala (programming language)">Vala',
#  '\n<li><a href="/wiki/Vim_(text_editor)#Vim_script" title="Vim (text editor)">Vim script',
#  '\n<li><a href="/wiki/Ethereum#Smart_contracts" title="Ethereum">Viper (Ethereum/Ether (ETH))',
#  '\n<li><a class="mw-redirect" href="/wiki/Visual_DataFlex" title="Visual DataFlex">Visual DataFlex',
#  '\n<li><a href="/wiki/Visual_DialogScript" title="Visual DialogScript">Visual DialogScript',
#  '\n<li><a href="/wiki/Visual_FoxPro" title="Visual FoxPro">Visual FoxPro',
#  '\n<li><a href="/wiki/Visual_J%2B%2B" title="Visual J++">Visual J++ (Visual J plus plus)',
#  '\n<li><a href="/wiki/AutoLISP" title="AutoLISP">Visual LISP',
#  '\n<li><a href="/wiki/Visual_Objects" title="Visual Objects">Visual Objects',
#  '\n<li><a href="/wiki/Visual_Prolog" title="Visual Prolog">Visual Prolog',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a class="mw-redirect" href="/wiki/WATFIV_(programming_language)" title="WATFIV (programming language)">WATFIV, WATFOR (WATerloo FORtran IV)',
#  '\n<li><a href="/wiki/WebAssembly" title="WebAssembly">WebAssembly',
#  '\n<li><a href="/wiki/WebDNA" title="WebDNA">WebDNA',
#  '\n<li><a href="/wiki/Whiley_(programming_language)" title="Whiley (programming language)">Whiley',
#  '\n<li><a class="mw-redirect" href="/wiki/Winbatch" title="Winbatch">Winbatch',
#  '\n<li><a href="/wiki/Wolfram_Language" title="Wolfram Language">Wolfram Language',
#  '\n<li><a href="/wiki/Wyvern_(programming_language)" title="Wyvern (programming language)">Wyvern',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a class="mw-redirect" href="/wiki/X%2B%2B" title="X++">X++ (X plus plus/Microsoft Dynamics AX)',
#  '\n<li><a href="/wiki/X10_(programming_language)" title="X10 (programming language)">X10',
#  '\n<li><a href="/wiki/XBase%2B%2B" title="XBase++">xBase++ (xBase plus plus)',
#  '\n<li><a href="/wiki/XBL" title="XBL">XBL',
#  '\n<li><a class="mw-redirect" href="/wiki/XC_(programming_language)" title="XC (programming language)">XC</a> (targets <a class="mw-redirect" href="/wiki/XCore_XS1" title="XCore XS1">XMOS architecture</a>)</li>\n<li><a href="/wiki/XHarbour" title="XHarbour">xHarbour',
#  '\n<li><a class="mw-redirect" href="/wiki/XL_(programming_language)" title="XL (programming language)">XL',
#  '\n<li><a href="/wiki/Xojo" title="Xojo">Xojo',
#  '\n<li><a href="/wiki/XOTcl" title="XOTcl">XOTcl',
#  '\n<li><a href="/wiki/XOD_(programming_language)" title="XOD (programming language)">Xod',
#  '\n<li><a href="/wiki/XPL" title="XPL">XPL',
#  '\n<li><a href="/wiki/XPL0" title="XPL0">XPL0',
#  '\n<li><a href="/wiki/XQuery" title="XQuery">XQuery',
#  '\n<li><a href="/wiki/XSB" title="XSB">XSB',
#  '\n<li><a href="/wiki/XSharp" title="XSharp">XSharp (X#)',
#  '\n<li><a href="/wiki/XSLT" title="XSLT">XSLT',
#  '\n<li><a href="/wiki/Xtend" title="Xtend">Xtend',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/Yorick_(programming_language)" title="Yorick (programming language)">Yorick',
#  '\n<li><a class="mw-redirect" href="/wiki/YQL_(programming_language)" title="YQL (programming language)">YQL',
#  '\n<li><a href="/wiki/Yoix" title="Yoix">Yoix',
#  '</ul></div>, <div class="div-col" style="column-width: 22em;">\n<ul><li><a href="/wiki/Z_notation" title="Z notation">Z notation',
#  '\n<li><a href="/wiki/Z_shell" title="Z shell">Z shell',
#  '\n<li><a class="mw-redirect" href="/wiki/Zebra_(programming_language)" title="Zebra (programming language)">Zebra, ZPL, ZPL2',
#  '\n<li><a href="/wiki/Zeno_(programming_language)" title="Zeno (programming language)">Zeno',
#  '\n<li><a class="mw-redirect" href="/wiki/ZetaLisp" title="ZetaLisp">ZetaLisp',
#  '\n<li><a href="/wiki/Zig_(programming_language)" title="Zig (programming language)">Zig',
#  '\n<li><a href="/wiki/Zonnon" title="Zonnon">Zonnon',
#  '\n<li><a href="/wiki/ZOPL" title="ZOPL">ZOPL',
#  '\n<li><a href="/wiki/ZPL_(programming_language)" title="ZPL (programming language)">ZPL',
#  '\n<li><a href="/wiki/Z%2B%2B" title="Z++">Z++',
#  '</ul></div>]']

# %%
for item in listed:
    if '22em' in str(item):
        listed.pop(listed.index(item))

links = []
titles = []

for i in range(len(listed)-1):
    list_of_title_and_link = listed[i].split('href=')[1].split('title')
    link = list_of_title_and_link[0].split('"')[1]
    links.append(link)
    title = list_of_title_and_link[1].split('"')[1]
    titles.append(title)

# %%
df = pd.DataFrame({'Language': titles, 'Link': links})
for title in df["Language"]:
    if '(programming language)' in str(title):
        titleNew = title.strip(' (programming language)')
        df.loc[df['Language'] == title, 'Language'] = titleNew
df
# Out:
#        Language                               Link
# 0    A-0 System                   /wiki/A-0_System
# 1            A+  /wiki/A%2B_(programming_language)
# 2          ABAP                         /wiki/ABAP
# 3           ABC   /wiki/ABC_(programming_language)
# 4     ABC ALGOL                    /wiki/ABC_ALGOL
# ..          ...                                ...
# 625           Z   /wiki/Zig_(programming_language)
# 626      Zonnon                       /wiki/Zonnon
# 627        ZOPL                         /wiki/ZOPL
# 628         ZPL   /wiki/ZPL_(programming_language)
# 629         Z++                      /wiki/Z%2B%2B
#
# [630 rows x 2 columns]

# %%
definitions_list = []
for link in df['Link']:
    link = "https://en.wikipedia.org"+ link
    res = requests.get(link)
    soup= BeautifulSoup(res.text, 'lxml')

    definition = soup.find('p').getText()
    definitions_list.append(definition)

df['Definition'] = definitions_list
df
# Out:
#        Language                               Link  \
# 0    A-0 System                   /wiki/A-0_System
# 1            A+  /wiki/A%2B_(programming_language)
# 2          ABAP                         /wiki/ABAP
# 3           ABC   /wiki/ABC_(programming_language)
# 4     ABC ALGOL                    /wiki/ABC_ALGOL
# ..          ...                                ...
# 625           Z   /wiki/Zig_(programming_language)
# 626      Zonnon                       /wiki/Zonnon
# 627        ZOPL                         /wiki/ZOPL
# 628         ZPL   /wiki/ZPL_(programming_language)
# 629         Z++                      /wiki/Z%2B%2B
#
#                                             Definition
# 0    The A-0 system (Arithmetic Language version 0)...
# 1    A+ is a high-level, interactive, interpreted a...
# 2    ABAP (Advanced Business Application Programmin...
# 3    ABC is an imperative general-purpose programmi...
# 4    ABC ALGOL is an extension of the programming l...
# ..                                                 ...
# 625  Zig is an imperative, general-purpose, statica...
# 626                                                 \n
# 627  ZOPL is a programming language created by Geac...
# 628  ZPL (short for Z-level Programming Language) i...
# 629                                                 \n
#
# [630 rows x 3 columns]

# %%
# save df to csv
df.to_csv('programming_languages_def.csv')

# %%
df_show = pd.read_csv('programming_languages_def.csv')
df_show.head(7)
# Out:
#    Unnamed: 0    Language                                 Link  \
# 0           0  A-0 System                     /wiki/A-0_System
# 1           1          A+    /wiki/A%2B_(programming_language)
# 2           2        ABAP                           /wiki/ABAP
# 3           3         ABC     /wiki/ABC_(programming_language)
# 4           4   ABC ALGOL                      /wiki/ABC_ALGOL
# 5           5         ACC     /wiki/ACC_(programming_language)
# 6           6      Accent  /wiki/Accent_(programming_language)
#
#                                           Definition
# 0  The A-0 system (Arithmetic Language version 0)...
# 1  A+ is a high-level, interactive, interpreted a...
# 2  ABAP (Advanced Business Application Programmin...
# 3  ABC is an imperative general-purpose programmi...
# 4  ABC ALGOL is an extension of the programming l...
# 5  ACC is a near-C compiler for the MS-DOS operat...
# 6  Rational Synergy is a software tool that provi...
