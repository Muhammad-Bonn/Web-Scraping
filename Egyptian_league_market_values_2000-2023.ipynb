# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.transfermarkt.com/egyptian-premier-league/startseite/wettbewerb/EGY1/plus/?saison_id={year}"

years = list(range(2000, 2025))
season_links = []

for year in years:
    url = base_url.format(year=year)
    season_links.append({'year': year,'url': url})

# %%
def get_df(item):
    url = item['url']
    year = item['year']
    response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    soup = BeautifulSoup(response.content, 'lxml')
    table = soup.find('table', class_='items')
    rows = table.find_all('tr', {'class': ['odd', 'even']})
    data = []

    for row in rows:
        team_cell = row.find_all('td')[1]
        link_tag = team_cell.find('a')
        if link_tag and 'href' in link_tag.attrs:
            team_url = "https://www.transfermarkt.com" + link_tag['href']
        else:
            team_url = None

        cols = row.find_all('td')
        club = cols[1].text.strip()
        squad = cols[2].text.strip()
        avg_age = cols[3].text.strip()
        foreigners = cols[4].text.strip()
        avg_value = cols[5].text.strip().replace('€', '').replace('k', '000').replace('m', '000000')
        total_value = cols[6].text.strip().replace('€', '').replace('k', '000').replace('m', '000000')
        data.append([club, squad, avg_age, foreigners, avg_value, total_value, team_url])


    df = pd.DataFrame(data, columns=['Club', 'Squad Size', 'Avg Age', 'Foreigners',
                                     'Avg Market Value (EUR)', 'Total Market Value (EUR)', 'Team URL'])
    df['Squad Size'] = pd.to_numeric(df['Squad Size'], errors='coerce')
    df['Avg Age'] = pd.to_numeric(df['Avg Age'], errors='coerce')
    df['Foreigners'] = pd.to_numeric(df['Foreigners'], errors='coerce')
    df['Avg Market Value (EUR)'] = pd.to_numeric(df['Avg Market Value (EUR)'], errors='coerce')
    df['Total Market Value (EUR)'] = pd.to_numeric(df['Total Market Value (EUR)'], errors='coerce')
    df['Year'] = year

    return df

# %%
data = []
for item in season_links:
    try:
        df = get_df(item)
        data.append(df)
    except Exception as e:
        print(f"Failed: {url}\n   Error: {e}")
        continue

# %%
data = pd.concat(data, ignore_index=True)

# %%
second_try = []

for year in years:
    existed_years = data['Year'].value_counts().index.tolist()
    if year not in existed_years:
        second_try.append(year)

# %%
second_try
# Out:
# [2011, 2012, 2013, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
existed_years
# Out:
# [2014, 2006, 2007, 2008, 2009, 2010, 2001, 2000, 2003, 2002, 2004, 2005]

# %%
second_links= []
for year in second_try:
    url = base_url.format(year=year)
    second_links.append({'year': year,'url': url})

# %%
second_data = []
for item in second_links:
    try:
        df = get_df(item)
        second_data.append(df)
    except Exception as e:
        print(f"Failed: {url}\n   Error: {e}")
        continue
# Out:
# Failed: https://www.transfermarkt.com/egyptian-premier-league/startseite/wettbewerb/EGY1/plus/?saison_id=2024
#    Error: 'NoneType' object has no attribute 'find_all'
# Failed: https://www.transfermarkt.com/egyptian-premier-league/startseite/wettbewerb/EGY1/plus/?saison_id=2024
#    Error: 'NoneType' object has no attribute 'find_all'

# %%
second_data = pd.concat(second_data, ignore_index=True)

# %%
second_data
# Out:
#                      Club  Squad Size  Avg Age  Foreigners  \
# 0              Al Ahly FC          31     27.4           3
# 1              Zamalek SC          31     26.4           4
# 2              Ismaily SC          29     26.8           5
# 3                Enppi SC          32     26.0           4
# 4             El Masry SC          27     26.4           2
# ..                    ...         ...      ...         ...
# 198              Enppi SC          43     24.5           4
# 199            Ismaily SC          56     24.8           4
# 200  Baladiyat El Mahalla          52     25.5          11
# 201           El Gouna FC          43     25.5           9
# 202         El Dakhlia SC          55     25.7           7
#
#      Avg Market Value (EUR)  Total Market Value (EUR)  \
# 0                  613000.0                     19.00
# 1                  502000.0                     15.58
# 2                  327000.0                      9.48
# 3                  183000.0                      5.85
# 4                  189000.0                      5.10
# ..                      ...                       ...
# 198                137000.0                      5.90
# 199                100000.0                      5.58
# 200                 94000.0                      4.90
# 201                111000.0                      4.78
# 202                 78000.0                      4.30
#
#                                               Team URL  Year
# 0    https://www.transfermarkt.com/el-ahly-kairo/st...  2011
# 1    https://www.transfermarkt.com/zamalek-sc/start...  2011
# 2    https://www.transfermarkt.com/ismaily-sc/start...  2011
# 3    https://www.transfermarkt.com/enppi-sc/startse...  2011
# 4    https://www.transfermarkt.com/el-masry-sc/star...  2011
# ..                                                 ...   ...
# 198  https://www.transfermarkt.com/enppi-sc/startse...  2023
# 199  https://www.transfermarkt.com/ismaily-sc/start...  2023
# 200  https://www.transfermarkt.com/baladiya-mahalla...  2023
# 201  https://www.transfermarkt.com/el-gouna-fc/star...  2023
# 202  https://www.transfermarkt.com/el-dakhlia-sc/st...  2023
#
# [203 rows x 8 columns]

# %%
final_data = pd.concat([data, second_data], ignore_index=True)

# %%
Ahly = final_data[final_data['Club']=='Al Ahly FC']
Zamalek = final_data[final_data['Club']=='Zamalek SC']
Ismaily  = final_data[final_data['Club']=='Ismaily SC']

# %%
Ismaily
# Out:
#            Club  Squad Size  Avg Age  Foreigners  Avg Market Value (EUR)  \
# 3    Ismaily SC          28     25.2           3                     NaN
# 17   Ismaily SC          27     24.6           3                     NaN
# 31   Ismaily SC          34     24.3           3                     NaN
# 44   Ismaily SC          37     23.4           5                     NaN
# 57   Ismaily SC          32     23.9           4                 59000.0
# 73   Ismaily SC          31     24.1           3                 24000.0
# 86   Ismaily SC          30     25.1           3                 70000.0
# 102  Ismaily SC          29     25.0           4                309000.0
# 118  Ismaily SC          34     25.2           4                223000.0
# 134  Ismaily SC          36     26.2           6                324000.0
# 150  Ismaily SC          35     25.6           4                261000.0
# 166  Ismaily SC          38     24.6           6                230000.0
# 186  Ismaily SC          29     26.8           5                327000.0
# 205  Ismaily SC          41     24.5           5                173000.0
# 223  Ismaily SC          35     24.6           5                195000.0
# 245  Ismaily SC          37     25.2           3                224000.0
# 264  Ismaily SC          39     24.9           4                184000.0
# 281  Ismaily SC          35     25.2           4                331000.0
# 301  Ismaily SC          44     25.3           7                235000.0
# 320  Ismaily SC          37     24.2           5                179000.0
# 337  Ismaily SC          44     25.1           5                187000.0
# 356  Ismaily SC          52     25.3           9                179000.0
# 383  Ismaily SC          56     24.8           4                100000.0
#
#      Total Market Value (EUR)  \
# 3                         NaN
# 17                        NaN
# 31                        NaN
# 44                        NaN
# 57                       1.90
# 73                  750000.00
# 86                       2.10
# 102                      8.98
# 118                      7.58
# 134                     11.65
# 150                      9.13
# 166                      8.73
# 186                      9.48
# 205                      7.10
# 223                      6.83
# 245                      8.30
# 264                      7.18
# 281                     11.58
# 301                     10.33
# 320                      6.63
# 337                      8.23
# 356                      9.33
# 383                      5.58
#
#                                               Team URL  Year
# 3    https://www.transfermarkt.com/ismaily-sc/start...  2000
# 17   https://www.transfermarkt.com/ismaily-sc/start...  2001
# 31   https://www.transfermarkt.com/ismaily-sc/start...  2002
# 44   https://www.transfermarkt.com/ismaily-sc/start...  2003
# 57   https://www.transfermarkt.com/ismaily-sc/start...  2004
# 73   https://www.transfermarkt.com/ismaily-sc/start...  2005
# 86   https://www.transfermarkt.com/ismaily-sc/start...  2006
# 102  https://www.transfermarkt.com/ismaily-sc/start...  2007
# 118  https://www.transfermarkt.com/ismaily-sc/start...  2008
# 134  https://www.transfermarkt.com/ismaily-sc/start...  2009
# 150  https://www.transfermarkt.com/ismaily-sc/start...  2010
# 166  https://www.transfermarkt.com/ismaily-sc/start...  2014
# 186  https://www.transfermarkt.com/ismaily-sc/start...  2011
# 205  https://www.transfermarkt.com/ismaily-sc/start...  2012
# 223  https://www.transfermarkt.com/ismaily-sc/start...  2013
# 245  https://www.transfermarkt.com/ismaily-sc/start...  2015
# 264  https://www.transfermarkt.com/ismaily-sc/start...  2016
# 281  https://www.transfermarkt.com/ismaily-sc/start...  2017
# 301  https://www.transfermarkt.com/ismaily-sc/start...  2018
# 320  https://www.transfermarkt.com/ismaily-sc/start...  2019
# 337  https://www.transfermarkt.com/ismaily-sc/start...  2020
# 356  https://www.transfermarkt.com/ismaily-sc/start...  2021
# 383  https://www.transfermarkt.com/ismaily-sc/start...  2023

# %%
DATA = pd.read_csv('egyptian_league_market_values.csv')

# %%
DATA.head()
# Out:
#                     Club  Squad Size  Avg Age  Foreigners  \
# 0             Al Ahly FC          34     23.9           4
# 1             Zamalek SC          29     26.3           0
# 2        El Mokawloon SC          23     25.0           0
# 3             Ismaily SC          28     25.2           3
# 4  Ittihad Alexandria SC          28     25.6           2
#
#    Avg Market Value (EUR)  Total Market Value (EUR)  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
#
#                                             Team URL  Year
# 0  https://www.transfermarkt.com/el-ahly-kairo/st...  2000
# 1  https://www.transfermarkt.com/zamalek-sc/start...  2000
# 2  https://www.transfermarkt.com/el-mokawloon-sc/...  2000
# 3  https://www.transfermarkt.com/ismaily-sc/start...  2000
# 4  https://www.transfermarkt.com/ittihad-alexandr...  2000

# %%
DATA.tail()
# Out:
#                      Club  Squad Size  Avg Age  Foreigners  \
# 382              Enppi SC          43     24.5           4
# 383            Ismaily SC          56     24.8           4
# 384  Baladiyat El Mahalla          52     25.5          11
# 385           El Gouna FC          43     25.5           9
# 386         El Dakhlia SC          55     25.7           7
#
#      Avg Market Value (EUR)  Total Market Value (EUR)  \
# 382                137000.0                      5.90
# 383                100000.0                      5.58
# 384                 94000.0                      4.90
# 385                111000.0                      4.78
# 386                 78000.0                      4.30
#
#                                               Team URL  Year
# 382  https://www.transfermarkt.com/enppi-sc/startse...  2023
# 383  https://www.transfermarkt.com/ismaily-sc/start...  2023
# 384  https://www.transfermarkt.com/baladiya-mahalla...  2023
# 385  https://www.transfermarkt.com/el-gouna-fc/star...  2023
# 386  https://www.transfermarkt.com/el-dakhlia-sc/st...  2023
