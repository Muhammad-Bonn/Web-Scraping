# %% [markdown]
# # El Da7ee7 Episodes Data Analysis
#
# This project is an exploratory data analysis (EDA) of the popular Arabic YouTuber Ahmed El-Ghandour **El Da7ee7**. The goal is to analyze and visualize patterns across episodes, including topics, durations, views, and release dates.
#
# Content:
# - [Dataset Overview](#Dataset-Overview)
# - [Duration vs Views](#Duration-vs-Views)
# - [Removing outliers](#Removing-outliers)

# %% [markdown]
# # Dataset Overview

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import re
import json

# %%
data = pd.read_excel('cleaned_d7ee7_data.xlsx')

# %%
data.head()
# Out:
#                                             Title  \
# 0                ابن مجدي عبد الغني (Epigenetics)
# 1                ابن مجدي عبد الغني (Epigenetics)
# 2                                        إنت جامد
# 3        ماذا قال عن الأب والأم والعلاقات عن بعد؟
# 4  ليه ما بنتكلمش زي الاجانب؟ (Speech Perception)
#
#                                          Description                 Channel  \
# 0  مجدي عبد الغني أفحم الناس بضربة الجزاء لكن في ...         Da7ee7 - الدحيح
# 1  مجدي عبد الغني أفحم الناس بضربة الجزاء لكن في ...         Da7ee7 - الدحيح
# 2  لمتابعة "الدحيح" \nhttp://ajar.io/ryr6j\n\nالد...               AJ+ كبريت
# 3  ماذا قال الدحيح عن الأب والأم والعلاقات عن بعد...  New Media Academy Life
# 4  لمشاهدة الحلقة الأولي من الكورة مع السلامة - ا...         Da7ee7 - الدحيح
#
#                                            URL    Views   Likes  Comments  \
# 0  https://www.youtube.com/watch?v=shkThcSCWqM   617313   22053       780
# 1  https://www.youtube.com/watch?v=shkThcSCWqM   617313   22053       780
# 2  https://www.youtube.com/watch?v=TG3vHrlgczM  1627517   61436      1720
# 3  https://www.youtube.com/watch?v=UXbGqkCE7Qw    96514    2865       100
# 4  https://www.youtube.com/watch?v=z9VlaSRmcWE  2232645  105597      2060
#
#   Duration  Duration_seconds
# 0  PT4M28S               268
# 1  PT4M28S               268
# 2  PT4M29S               269
# 3  PT4M44S               284
# 4  PT4M46S               286

# %%
data.tail()
# Out:
#                                                  Title  \
# 613                                       دونالد ترامب
# 614                                ألف سنة من الإنهيار
# 615                                           الصعاليك
# 616                                         جراح القلب
# 617  فلسطين .. حكاية الأرض Palestine .. a Tale of Land
#
#                                            Description  \
# 613  في رحلة تحوله من رجل أعمال ونجم تليفزيون الواق...
# 614  لماذا لا يتكلم المصريون الحاليون نفس لغة المصر...
# 615  في قلب شبه الجزيرة العربية، خرج مجموعة من الرج...
# 616  تدور الحلقة حول الجراح السير مجدي يعقوب وكيف ت...
# 617  هكذا بدأت الحكاية\n0:00-12:58 الطنطورة \n12:59...
#
#                     Channel                                          URL  \
# 613  New Media Academy Life  https://www.youtube.com/watch?v=uA-h1CmScHQ
# 614  New Media Academy Life  https://www.youtube.com/watch?v=HG3xQjwenTc
# 615  New Media Academy Life  https://www.youtube.com/watch?v=WQj_OUBaMg0
# 616  New Media Academy Life  https://www.youtube.com/watch?v=9ZTCUyhoknU
# 617  New Media Academy Life  https://www.youtube.com/watch?v=f0oy-NicIgE
#
#         Views    Likes  Comments   Duration  Duration_seconds
# 613   5064246   102744      3283   PT49M42S              2982
# 614   3442237    84557      7442   PT51M19S              3079
# 615   4006370    95328      4472   PT53M43S              3223
# 616   3765475   172175      5960   PT58M39S              3519
# 617  25832260  1203867     56842  PT1H2M36S              3756

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618 entries, 0 to 617
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             618 non-null    object
#  1   Description       618 non-null    object
#  2   Channel           618 non-null    object
#  3   URL               618 non-null    object
#  4   Views             618 non-null    int64
#  5   Likes             618 non-null    int64
#  6   Comments          618 non-null    int64
#  7   Duration          618 non-null    object
#  8   Duration_seconds  618 non-null    int64
# dtypes: int64(4), object(5)
# memory usage: 43.6+ KB

# %%
data.describe()
# Out:
#               Views         Likes      Comments  Duration_seconds
# count  6.180000e+02  6.180000e+02    618.000000        618.000000
# mean   3.377930e+06  1.252703e+05   3740.061489       1212.637540
# std    2.167914e+06  8.534399e+04   3904.670807        578.949612
# min    7.858300e+04  2.246000e+03     54.000000        268.000000
# 25%    2.208437e+06  7.845475e+04   1933.500000        746.750000
# 50%    3.057056e+06  1.087010e+05   3051.500000       1172.500000
# 75%    4.168032e+06  1.554615e+05   4363.750000       1598.750000
# max    2.583226e+07  1.203867e+06  56842.000000       3756.000000

# %%
data.duplicated().sum()
# Out:
# np.int64(24)

# %%
data.drop_duplicates(subset=['URL'], inplace=True)

# %%
# Add new column with duration in minutes, rounded to nearest whole number
data['Duration_minutes'] = (data['Duration_seconds'] / 60).round().astype(int)

# %%
# Function to remove Arabic letters from channel name
def remove_arabic(text):
    # Arabic Unicode block: \u0600 to \u06FF
    # This regex removes all Arabic characters from the string
    return re.sub(r'[\u0600-\u06FF]+', '', text).strip()

# %%
# Apply the function to the 'Channel' column to clean Arabic letters
data['Channel'] = data['Channel'].apply(remove_arabic)

# %% [markdown]
# ## Duration vs Views

# %%
# plot Duration of episode vs Views, Likes, and Comments
# Set up 3 horizontal subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

# Metrics for X-axis
metrics = ['Views', 'Likes', 'Comments']

# Draw scatter plots without individual legends
for i, metric in enumerate(metrics):
    sns.scatterplot(data=data, x=metric, y='Duration_minutes', hue='Channel', ax=axes[i], legend=False)
    axes[i].set_title(f'Duration vs {metric}')
    axes[i].set_xlabel(metric)
    if i == 0:
        axes[i].set_ylabel('Duration (minutes)')
    else:
        axes[i].set_ylabel('')
        
plt.tight_layout()
plt.show()

# %%
# Plot heatmap for views, likes and comments
numeric_data = data[['Views', 'Likes', 'Comments', 'Duration_seconds']]
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Video Metrics')
plt.show()

# %%
# Draw scatter plot for Views vs Duration in minutes
fig, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(
    data=data,
    x='Views',
    y='Duration_minutes',
    hue='Channel',
    ax=ax
)

# Set axis titles and main title
ax.set_title('Video Duration (minutes) vs Views')
ax.set_xlabel('Views')
ax.set_ylabel('Duration (minutes)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Removing shorts

# %%
# Remove episodes that are likely Shorts or excerpts
# These often start with "ماذا قال الدحيح عن" and are not full episodes

data.sort_values(by='Views',ascending=False).tail(5)
# Out:
#                                         Title  \
# 33      ماذا قال عن شخصيات وأحداث من التاريخ؟
# 16  ماذا قال عن الرعب والزلازل ونهاية العالم؟
# 19          ماذا قال عن الحيوانات وتوم وجيري؟
# 10      ماذا قال عن الحساسية والموت والمقابر؟
# 32               ماذا قال عن برامجنا المفضلة؟
#
#                                           Description                 Channel  \
# 33  ماذا قال الدحيح عن شخصيات وأحداث من التاريخ؟\n...  New Media Academy Life
# 16  ماذا قال الدحيح عن الرعب والزلازل ونهاية العال...  New Media Academy Life
# 19  ماذا قال الدحيح عن الحيوانات وتوم وجيري؟\n\n#ا...  New Media Academy Life
# 10  ماذا قال الدحيح عن الحساسية والموت والمقابر؟ \...  New Media Academy Life
# 32  ماذا قال الدحيح عن برامجنا المفضلة؟\n\n#الدحيح...  New Media Academy Life
#
#                                             URL  Views  Likes  Comments  \
# 33  https://www.youtube.com/watch?v=rLR_EsEUmuY  91963   2257        86
# 16  https://www.youtube.com/watch?v=zTXXTgdz4Sk  88695   2306        54
# 19  https://www.youtube.com/watch?v=pCCLPOVOj9c  88553   2246        69
# 10  https://www.youtube.com/watch?v=upJF5V4AD1Y  85611   2341        78
# 32  https://www.youtube.com/watch?v=hUN2AJU-Ty4  78583   2309        97
#
#    Duration  Duration_seconds  Duration_minutes
# 33   PT7M9S               429                 7
# 16   PT6M4S               364                 6
# 19  PT6M22S               382                 6
# 10  PT5M12S               312                 5
# 32   PT7M8S               428                 7

# %%
# Filter and display episodes whose descriptions start with the target phrase
shorts_like_episodes = data[data['Description'].str.startswith("ماذا قال الدحيح عن", na=False)]

# Display them
shorts_like_episodes[['Title', 'Description', 'Channel', 'Views', 'Duration_minutes']].reset_index(drop=True)
# Out:
#                                        Title  \
# 0   ماذا قال عن الأب والأم والعلاقات عن بعد؟
# 1      ماذا قال عن الحساسية والموت والمقابر؟
# 2         ماذا قال عن الشغف والتشاؤم والخوف؟
# 3  ماذا قال عن الرعب والزلازل ونهاية العالم؟
# 4          ماذا قال عن الطبخ والأكل والدايت؟
# 5          ماذا قال عن الحيوانات وتوم وجيري؟
# 6      ماذا قال عن مقاييس الجمال و الأتيكيت؟
# 7                  ماذا قال عن أصعب المواقف؟
# 8               ماذا قال عن برامجنا المفضلة؟
# 9      ماذا قال عن شخصيات وأحداث من التاريخ؟
#
#                                          Description                 Channel  \
# 0  ماذا قال الدحيح عن الأب والأم والعلاقات عن بعد...  New Media Academy Life
# 1  ماذا قال الدحيح عن الحساسية والموت والمقابر؟ \...  New Media Academy Life
# 2  ماذا قال الدحيح عن الشغف والتشاؤم والخوف؟ \n\n...  New Media Academy Life
# 3  ماذا قال الدحيح عن الرعب والزلازل ونهاية العال...  New Media Academy Life
# 4  ماذا قال الدحيح عن الطبخ والأكل والدايت؟ \n\nم...  New Media Academy Life
# 5  ماذا قال الدحيح عن الحيوانات وتوم وجيري؟\n\n#ا...  New Media Academy Life
# 6  ماذا قال الدحيح عن مقاييس الجمال و الأتيكيت؟ \...  New Media Academy Life
# 7  ماذا قال الدحيح عن أصعب المواقف؟\n\n#الدحيح \n...  New Media Academy Life
# 8  ماذا قال الدحيح عن برامجنا المفضلة؟\n\n#الدحيح...  New Media Academy Life
# 9  ماذا قال الدحيح عن شخصيات وأحداث من التاريخ؟\n...  New Media Academy Life
#
#     Views  Duration_minutes
# 0   96514                 5
# 1   85611                 5
# 2  360587                 6
# 3   88695                 6
# 4  296728                 6
# 5   88553                 6
# 6   92148                 7
# 7   93877                 7
# 8   78583                 7
# 9   91963                 7

# %%
data = data[~data['Description'].str.startswith("ماذا قال الدحيح عن", na=False)]

# %%
data.sort_values(by='Views',ascending=False).tail(5)
# Out:
#                                          Title  \
# 11           الكفتجي (Selffulfilling Prophecy)
# 40  بوشكاش و الانتخابات (DunningKruger Effect)
# 21  سولوفان الارهابي (Behavioral Confirmation)
# 6              من غير ضرائب (Transfer Pricing)
# 5                   الطويل الزعزوع (Heightism)
#
#                                           Description   Channel  \
# 11  شايف ايه في الكوبايا ؟\nhttps://www.patreon.co...  Da7ee7 -
# 40  الغبي فاكر نفسه ذكي و الذكي فاكر نفسه غبي ! \n...  Da7ee7 -
# 21  حلقة تقيلة شوية :) يا جماعا سولوفان كان كويس !...  Da7ee7 -
# 6   تسريب اوراق بنما ! \nSubscribe Here http://bit...  Da7ee7 -
# 5   الطول هيبة والقصر خيبة ! \nhttps://www.patreon...  Da7ee7 -
#
#                                             URL   Views  Likes  Comments  \
# 11  https://www.youtube.com/watch?v=obhciS90EWA  491475  17008       294
# 40  https://www.youtube.com/watch?v=hA2y3DwLYug  451964  18034       773
# 21  https://www.youtube.com/watch?v=ky_M4DE0Y4s  431384  14057       319
# 6   https://www.youtube.com/watch?v=LLqlyv6OEHA  426819  13756       297
# 5   https://www.youtube.com/watch?v=TG7xcl1dMnM  378430  12189       330
#
#    Duration  Duration_seconds  Duration_minutes
# 11  PT5M46S               346                 6
# 40  PT7M23S               443                 7
# 21  PT6M28S               388                 6
# 6    PT5M7S               307                 5
# 5   PT4M51S               291                 5

# %% [markdown]
# ## Removing outliers

# %% [markdown]
# ##### We remove episodes with extremely high or low views because:
# ##### - Very high views might be viral/special events not representative of typical performance
# ##### - Very low views could be due to upload errors, unlisted videos, or bad timing

# %%
# Calculate the average number of views
average_views = data['Views'].mean()
print(f"Average Views: {average_views:,.0f}")
# Out:
# Average Views: 3,536,348

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = data['Views'].quantile(0.25)
Q3 = data['Views'].quantile(0.75)

# Interquartile Range
IQR = Q3 - Q1

# Outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Upper bound (outlier threshold): {upper_bound:,.0f}")
# Out:
# Upper bound (outlier threshold): 7,100,944

# %%
# Sort episodes by Views in descending order
top_viewed_episodes = data.sort_values(by='Views', 
                                       ascending=False)[['Title', 'Views', 'Duration_minutes', 'Channel']].reset_index(drop=True)

# Display the top results
IQR_method = top_viewed_episodes[top_viewed_episodes['Views']>=upper_bound]

print(f'Episodes to be removed: {len(IQR_method)}')
# Out:
# Episodes to be removed: 24

# %%
# Trying Modified Z-Score (Median Absolute Deviation - MAD)
median = data['Views'].median()
mad = np.median(np.abs(data['Views'] - median))

data['Views_mod_z'] = 0.6745 * (data['Views'] - median) / mad

# Any video with |Modified Z| > 3.5 is considered an outlier
outliers_mod_z = data[np.abs(data['Views_mod_z']) > 3.5]

print(f'Episodes to be removed: {len(outliers_mod_z)}')
# Out:
# Episodes to be removed: 16

# %%
# Both Methods to remove many and importanat episodes
# we only remove biggest two episodes in views
top_viewed_episodes.head()
# Out:
#                                                Title     Views  \
# 0  فلسطين .. حكاية الأرض Palestine .. a Tale of Land  25832260
# 1                             الحرب العالمية الثانية  23855609
# 2                             الفراعنة في 1602 ثانية  12175241
# 3                                               هتلر  12013980
# 4                                     بناء الأهرامات  10421843
#
#    Duration_minutes                 Channel
# 0                63  New Media Academy Life
# 1                39                     AJ+
# 2                27                     AJ+
# 3                14                     AJ+
# 4                23    Museum of The Future

# %%
titles_to_remove = top_viewed_episodes.head(2)['Title']
data = data[~data['Title'].isin(titles_to_remove)].reset_index(drop=True)

# %%
# Draw scatter plot for Views vs Duration in minutes
fig, ax = plt.subplots(figsize=(12, 6))
sns.scatterplot(
    data=data,
    x='Duration_minutes',
    y='Views',
    hue='Channel',
    ax=ax
)

# Set axis titles and main title
ax.set_title('Views vs Video Duration (minutes)')
ax.set_xlabel('Duration (minutes)')
ax.set_ylabel('Views (millions)')

# Apply y-axis formatter to millions
million_formatter = FuncFormatter(lambda x, _: f'{x/1_000_000:.1f} M')
ax.yaxis.set_major_formatter(million_formatter)  # <-- fixed line

plt.tight_layout()
plt.show()
